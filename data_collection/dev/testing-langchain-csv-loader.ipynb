# %%
import pandas as pd
import pickle
import requests
from bs4 import BeautifulSoup
import trafilatura
import re
import random
from langchain.text_splitter import RecursiveCharacterTextSplitter
from langchain.vectorstores import Chroma
from langchain.chains import VectorDBQA
from langchain.llms import OpenAI
from langchain.text_splitter import RecursiveCharacterTextSplitter
from langchain.embeddings import OpenAIEmbeddings
from langchain.chains import RetrievalQA

df = pd.read_csv("./data/chunks_from_html.csv")

# %%
data_folder = "/home/msaad/workspace/honors-thesis/data-collection/data/"
responses_dict = pickle.load(open(data_folder + "scraper_output.p", "rb"))

def get_text(item: tuple[str, requests.models.Response]) -> list:
    """
    Parses HTML for 'sentences', as described above.
    """
    key, response = item

    # Your BeautifulSoup object
    soup = BeautifulSoup(response.text, 'html.parser')

    # Create an empty list to hold the sentences
    long_texts = []

    # Define custom punctuation
    custom_punctuation = ',./?!:;$#&+*()"'

    # Loop through all the strings in the BeautifulSoup object
    for string in soup.stripped_strings:
        # Consider a long text as a text having 15 or more words
        if len(string.split()) >= 10: # NOTE July 17. Next run edit - 10 
            # Check if the string contains only alphanumeric, whitespace and custom punctuation characters
            if all(c.isalnum() or c.isspace() or c in custom_punctuation for c in string):
                # Check if the string contains more than 3 whitespaces in a row
                if not re.search(' {3,}', string):
                    long_texts.append(string)

    # NEW: Added so semantic search queries return bigger, more in context results.
    # "chunk" is a string of all the long sentences (as described above) separated by a space.
    chunk = "\n".join(long_texts)
    
    # OLD: return long_texts
    return chunk #key, 




def new_cleaning(response: requests.models.Response) -> str:
    return trafilatura.extract(response.text, include_tables=False)

# %%
urls = random.sample(list(responses_dict.keys()), 5)
urls
# Out:
# ['https://www2.brockport.edu/about/town_gown/communications_outreach.html',
#  'https://www2.brockport.edu/life/residential_life/housing_selection/spring',
#  'https://www2.brockport.edu/academics/kinesiology/athletic-training/opportunities',
#  'https://www2.brockport.edu/live/profiles/3381-eugeniya-iskrenova-ekiert',
#  'https://www2.brockport.edu/support/institutional-review-board/proposal-guidance']

# %%
output = []
for url in urls:
    response = responses_dict[url]
    output.append([get_text((url, response)), new_cleaning(response)])

# %%
len(responses_dict.keys())
# Out:
# 5413

# %%
[
word in 'test_admissions' for word in ]
# Out:
# [True, False]

# %%
'brockport.edu/life/' in 'https://www2.brockport.edu/life/welcome-week'
# Out:
# True

# %%
# Filter out to only successful requests (status code == 200)
res_dict = {}
for url, response in responses_dict.items():
    if response.status_code == 200:
        res_dict[url] = response

urls = res_dict.keys()

## Many of the URLs have .html on he end of it. This causes some duplication where there is a url with a .html and another without.
# This step filters them out, and standardizes it. If both exist, it'll remove the .html version, if only the .html version exists, it'll strip it and add it to the list.
html_urls = set()
non_html_urls = set()

for url in urls:
    if url.endswith('.html'):
        stripped_url = url[:-5]  # strip .html
        html_urls.add(stripped_url)
    else:
        non_html_urls.add(url)

# Filter out .html URLs if non-html version exists
urls = set(non_html_urls | (html_urls - non_html_urls))

# Standardize the _ and - to -. Many copies of URLs with differences.
urls = {url.replace('_', '-') for url in urls}

# Filter length of URL?
# urls = {url for url in urls if url.count('/') < 6}

# Get rid of "live". Just wayyyyy too many of them, mostly professor websites.
bad_list = ['brockport.edu/live/', 'brockport.edu/life/', 'archive', 'transfer-credit', 'research-foundation']
urls = {url for url in urls if all(word not in url for word in bad_list)}


# Important decision!! Going to limit URL length for all non-admissions/faid webpages. Need to filter this down more... A lot more... 
good_list = ['brockport.edu/admissions/', 'brockport.edu/academics/advisement/handbook']
new_url = set()
for url in urls:
    if any(word in url for word in good_list):
        new_url.add(url)
    elif url.count('/') < 5:
        new_url.add(url)
urls = new_url
        


len(urls)
# Out:
# 300

# %%
sorted(urls)
# Out:
# ['https://www2.brockport.edu',
#  'https://www2.brockport.edu/about',
#  'https://www2.brockport.edu/about/accountability',
#  'https://www2.brockport.edu/about/brockport-downtown',
#  'https://www2.brockport.edu/about/contact-us',
#  'https://www2.brockport.edu/about/diversity',
#  'https://www2.brockport.edu/about/economic-impact',
#  'https://www2.brockport.edu/about/facts',
#  'https://www2.brockport.edu/about/location',
#  'https://www2.brockport.edu/about/lodging',
#  'https://www2.brockport.edu/about/middlestates',
#  'https://www2.brockport.edu/about/president',
#  'https://www2.brockport.edu/about/privacy',
#  'https://www2.brockport.edu/about/strategic-plan',
#  'https://www2.brockport.edu/about/sustainability',
#  'https://www2.brockport.edu/about/title-ix',
#  'https://www2.brockport.edu/about/town-gown',
#  'https://www2.brockport.edu/academics',
#  'https://www2.brockport.edu/academics/academic-affairs',
#  'https://www2.brockport.edu/academics/advisement',
#  'https://www2.brockport.edu/academics/advisement/handbook',
#  'https://www2.brockport.edu/academics/advisement/handbook/academic-majors',
#  'https://www2.brockport.edu/academics/advisement/handbook/academic-programs',
#  'https://www2.brockport.edu/academics/advisement/handbook/accounting-major',
#  'https://www2.brockport.edu/academics/advisement/handbook/advise-expectations',
#  'https://www2.brockport.edu/academics/advisement/handbook/african-african-american-studies-major',
#  'https://www2.brockport.edu/academics/advisement/handbook/alcohol-substance-abuse-studies-major',
#  'https://www2.brockport.edu/academics/advisement/handbook/anthropology-major',
#  'https://www2.brockport.edu/academics/advisement/handbook/art-bfa-major',
#  'https://www2.brockport.edu/academics/advisement/handbook/art-major',
#  'https://www2.brockport.edu/academics/advisement/handbook/arts-for-children-dance-major',
#  'https://www2.brockport.edu/academics/advisement/handbook/arts-for-children-dance-studies-major',
#  'https://www2.brockport.edu/academics/advisement/handbook/arts-for-children-interdisciplinary-major-theatre-speciality',
#  'https://www2.brockport.edu/academics/advisement/handbook/arts-for-children-literary-major',
#  'https://www2.brockport.edu/academics/advisement/handbook/arts-for-children-major',
#  'https://www2.brockport.edu/academics/advisement/handbook/arts-for-children-music-major',
#  'https://www2.brockport.edu/academics/advisement/handbook/athletic-training',
#  'https://www2.brockport.edu/academics/advisement/handbook/biochemistry-major',
#  'https://www2.brockport.edu/academics/advisement/handbook/biology-major',
#  'https://www2.brockport.edu/academics/advisement/handbook/business-administration-major',
#  'https://www2.brockport.edu/academics/advisement/handbook/chemistry-certified-major',
#  'https://www2.brockport.edu/academics/advisement/handbook/chemistry-major',
#  'https://www2.brockport.edu/academics/advisement/handbook/childhood-inclusive-education-bilingual-track',
#  'https://www2.brockport.edu/academics/advisement/handbook/childhood-inclusive-education-multidisciplinary-track',
#  'https://www2.brockport.edu/academics/advisement/handbook/communication-studies',
#  'https://www2.brockport.edu/academics/advisement/handbook/computer-information-systems',
#  'https://www2.brockport.edu/academics/advisement/handbook/computer-science-major',
#  'https://www2.brockport.edu/academics/advisement/handbook/contact',
#  'https://www2.brockport.edu/academics/advisement/handbook/contractual-liberal-arts-major',
#  'https://www2.brockport.edu/academics/advisement/handbook/criminal-justice-major',
#  'https://www2.brockport.edu/academics/advisement/handbook/dance-major',
#  'https://www2.brockport.edu/academics/advisement/handbook/doctor-physical-therapy',
#  'https://www2.brockport.edu/academics/advisement/handbook/earth-science-major',
#  'https://www2.brockport.edu/academics/advisement/handbook/english-creative-writing-major',
#  'https://www2.brockport.edu/academics/advisement/handbook/english-literature-major',
#  'https://www2.brockport.edu/academics/advisement/handbook/environmental-science-major',
#  'https://www2.brockport.edu/academics/advisement/handbook/exercise-science',
#  'https://www2.brockport.edu/academics/advisement/handbook/finance-major',
#  'https://www2.brockport.edu/academics/advisement/handbook/french-major',
#  'https://www2.brockport.edu/academics/advisement/handbook/general-education',
#  'https://www2.brockport.edu/academics/advisement/handbook/geology-major',
#  'https://www2.brockport.edu/academics/advisement/handbook/grading-system',
#  'https://www2.brockport.edu/academics/advisement/handbook/health-care-administration-major',
#  'https://www2.brockport.edu/academics/advisement/handbook/health-science-major',
#  'https://www2.brockport.edu/academics/advisement/handbook/history-major',
#  'https://www2.brockport.edu/academics/advisement/handbook/international-business-economics-major',
#  'https://www2.brockport.edu/academics/advisement/handbook/international-studies-major',
#  'https://www2.brockport.edu/academics/advisement/handbook/introduction',
#  'https://www2.brockport.edu/academics/advisement/handbook/journalism-major',
#  'https://www2.brockport.edu/academics/advisement/handbook/kinesiology-major',
#  'https://www2.brockport.edu/academics/advisement/handbook/liberal-studies',
#  'https://www2.brockport.edu/academics/advisement/handbook/marketing-major',
#  'https://www2.brockport.edu/academics/advisement/handbook/mathematics-major',
#  'https://www2.brockport.edu/academics/advisement/handbook/medical-technology-major',
#  'https://www2.brockport.edu/academics/advisement/handbook/meteorology-major',
#  'https://www2.brockport.edu/academics/advisement/handbook/notes-updates',
#  'https://www2.brockport.edu/academics/advisement/handbook/nursing-major',
#  'https://www2.brockport.edu/academics/advisement/handbook/philosophy-major',
#  'https://www2.brockport.edu/academics/advisement/handbook/physical-education-teaching-certification',
#  'https://www2.brockport.edu/academics/advisement/handbook/physics-major',
#  'https://www2.brockport.edu/academics/advisement/handbook/political-science-major',
#  'https://www2.brockport.edu/academics/advisement/handbook/pre-health-biochemistry',
#  'https://www2.brockport.edu/academics/advisement/handbook/pre-health-biology',
#  'https://www2.brockport.edu/academics/advisement/handbook/pre-health-chemistry',
#  'https://www2.brockport.edu/academics/advisement/handbook/pre-health-other',
#  'https://www2.brockport.edu/academics/advisement/handbook/pre-law',
#  'https://www2.brockport.edu/academics/advisement/handbook/psychology-major',
#  'https://www2.brockport.edu/academics/advisement/handbook/public-health-education-major',
#  'https://www2.brockport.edu/academics/advisement/handbook/recreation-leisure-studies-major',
#  'https://www2.brockport.edu/academics/advisement/handbook/social-studies-adolescence-education',
#  'https://www2.brockport.edu/academics/advisement/handbook/social-studies-adolescence-inclusive-education',
#  'https://www2.brockport.edu/academics/advisement/handbook/social-work-major',
#  'https://www2.brockport.edu/academics/advisement/handbook/sociology-major',
#  'https://www2.brockport.edu/academics/advisement/handbook/spanish-major',
#  'https://www2.brockport.edu/academics/advisement/handbook/sport-management-major',
#  'https://www2.brockport.edu/academics/advisement/handbook/theatre-major',
#  'https://www2.brockport.edu/academics/advisement/handbook/water-resources-major',
#  'https://www2.brockport.edu/academics/advisement/handbook/women-gender-studies',
#  'https://www2.brockport.edu/academics/african-american',
#  'https://www2.brockport.edu/academics/aging',
#  'https://www2.brockport.edu/academics/anthropology',
#  'https://www2.brockport.edu/academics/art',
#  'https://www2.brockport.edu/academics/biology',
#  'https://www2.brockport.edu/academics/business-administration',
#  'https://www2.brockport.edu/academics/calendar',
#  'https://www2.brockport.edu/academics/career',
#  'https://www2.brockport.edu/academics/celt',
#  'https://www2.brockport.edu/academics/certification',
#  'https://www2.brockport.edu/academics/chemistry',
#  'https://www2.brockport.edu/academics/commencement',
#  'https://www2.brockport.edu/academics/communication',
#  'https://www2.brockport.edu/academics/community-justice',
#  'https://www2.brockport.edu/academics/community-reading',
#  'https://www2.brockport.edu/academics/computing-sciences',
#  'https://www2.brockport.edu/academics/counselor-education',
#  'https://www2.brockport.edu/academics/criminal-justice',
#  'https://www2.brockport.edu/academics/cstep',
#  'https://www2.brockport.edu/academics/dance',
#  'https://www2.brockport.edu/academics/delta-college',
#  'https://www2.brockport.edu/academics/eagle-success',
#  'https://www2.brockport.edu/academics/earth-sciences',
#  'https://www2.brockport.edu/academics/education-human-development',
#  'https://www2.brockport.edu/academics/educational-administration',
#  'https://www2.brockport.edu/academics/educational-opportunity-program',
#  'https://www2.brockport.edu/academics/engaged-learning',
#  'https://www2.brockport.edu/academics/english',
#  'https://www2.brockport.edu/academics/environmental-science',
#  'https://www2.brockport.edu/academics/field-experience',
#  'https://www2.brockport.edu/academics/film',
#  'https://www2.brockport.edu/academics/fine-arts',
#  'https://www2.brockport.edu/academics/general-education',
#  'https://www2.brockport.edu/academics/healthcare-studies',
#  'https://www2.brockport.edu/academics/history',
#  'https://www2.brockport.edu/academics/honors-college',
#  'https://www2.brockport.edu/academics/imsvi',
#  'https://www2.brockport.edu/academics/international-education',
#  'https://www2.brockport.edu/academics/journalism-broadcasting',
#  'https://www2.brockport.edu/academics/kinesiology',
#  'https://www2.brockport.edu/academics/legal-studies',
#  'https://www2.brockport.edu/academics/liberal-integrative',
#  'https://www2.brockport.edu/academics/mathematics',
#  'https://www2.brockport.edu/academics/mcnair',
#  'https://www2.brockport.edu/academics/migrant-education',
#  'https://www2.brockport.edu/academics/military-science',
#  'https://www2.brockport.edu/academics/modern-languages',
#  'https://www2.brockport.edu/academics/museum',
#  'https://www2.brockport.edu/academics/music',
#  'https://www2.brockport.edu/academics/neuroscience',
#  'https://www2.brockport.edu/academics/nursing',
#  'https://www2.brockport.edu/academics/online',
#  'https://www2.brockport.edu/academics/philosophy',
#  'https://www2.brockport.edu/academics/physics',
#  'https://www2.brockport.edu/academics/political-science',
#  'https://www2.brockport.edu/academics/pre-med',
#  'https://www2.brockport.edu/academics/professional-education',
#  'https://www2.brockport.edu/academics/programs',
#  'https://www2.brockport.edu/academics/programs.html?select=dg-grad',
#  'https://www2.brockport.edu/academics/psychology',
#  'https://www2.brockport.edu/academics/public-administration',
#  'https://www2.brockport.edu/academics/public-health',
#  'https://www2.brockport.edu/academics/recreation-leisure',
#  'https://www2.brockport.edu/academics/scholars-day',
#  'https://www2.brockport.edu/academics/school-arts-sciences',
#  'https://www2.brockport.edu/academics/school-business-management',
#  'https://www2.brockport.edu/academics/school-education-health-human',
#  'https://www2.brockport.edu/academics/schools-departments',
#  'https://www2.brockport.edu/academics/social-work',
#  'https://www2.brockport.edu/academics/sociology',
#  'https://www2.brockport.edu/academics/special-sessions',
#  'https://www2.brockport.edu/academics/stem',
#  'https://www2.brockport.edu/academics/success-center',
#  'https://www2.brockport.edu/academics/theatre-music',
#  'https://www2.brockport.edu/academics/tutoring',
#  'https://www2.brockport.edu/academics/washington',
#  'https://www2.brockport.edu/academics/women-gender',
#  'https://www2.brockport.edu/admissions',
#  'https://www2.brockport.edu/admissions-aid/brockport-bound',
#  'https://www2.brockport.edu/admissions-aid/cost',
#  'https://www2.brockport.edu/admissions-aid/financial-aid',
#  'https://www2.brockport.edu/admissions-aid/orientation',
#  'https://www2.brockport.edu/admissions-aid/request',
#  'https://www2.brockport.edu/admissions-aid/scholarships',
#  'https://www2.brockport.edu/admissions-aid/visit',
#  'https://www2.brockport.edu/admissions-aid/visit-video',
#  'https://www2.brockport.edu/admissions/accepted',
#  'https://www2.brockport.edu/admissions/apply',
#  'https://www2.brockport.edu/admissions/apply-to-brockport',
#  'https://www2.brockport.edu/admissions/apply/dual-admission',
#  'https://www2.brockport.edu/admissions/apply/faq',
#  'https://www2.brockport.edu/admissions/apply/first-year',
#  'https://www2.brockport.edu/admissions/apply/index',
#  'https://www2.brockport.edu/admissions/apply/non-degree',
#  'https://www2.brockport.edu/admissions/apply/readmission',
#  'https://www2.brockport.edu/admissions/apply/second-degree',
#  'https://www2.brockport.edu/admissions/apply/special-admission-requirements',
#  'https://www2.brockport.edu/admissions/apply/special-programs',
#  'https://www2.brockport.edu/admissions/apply/status',
#  'https://www2.brockport.edu/admissions/apply/transfer',
#  'https://www2.brockport.edu/admissions/apply/update',
#  'https://www2.brockport.edu/admissions/brockport-bound',
#  'https://www2.brockport.edu/admissions/brockport-bound/first-year-checklist',
#  'https://www2.brockport.edu/admissions/brockport-bound/transfer-checklist',
#  'https://www2.brockport.edu/admissions/contact',
#  'https://www2.brockport.edu/admissions/contact/ambassadors',
#  'https://www2.brockport.edu/admissions/contact/communication-team',
#  'https://www2.brockport.edu/admissions/contact/index',
#  'https://www2.brockport.edu/admissions/cost',
#  'https://www2.brockport.edu/admissions/cost-previous-21-22',
#  'https://www2.brockport.edu/admissions/degree-completion',
#  'https://www2.brockport.edu/admissions/directory',
#  'https://www2.brockport.edu/admissions/information',
#  'https://www2.brockport.edu/admissions/information/accepted',
#  'https://www2.brockport.edu/admissions/information/counselors',
#  'https://www2.brockport.edu/admissions/information/eop',
#  'https://www2.brockport.edu/admissions/information/eop/financial-review-process',
#  'https://www2.brockport.edu/admissions/information/eop/index',
#  'https://www2.brockport.edu/admissions/information/first-year',
#  'https://www2.brockport.edu/admissions/information/first-year/home-school',
#  'https://www2.brockport.edu/admissions/information/first-year/index',
#  'https://www2.brockport.edu/admissions/information/returning-adults',
#  'https://www2.brockport.edu/admissions/information/veterans',
#  'https://www2.brockport.edu/admissions/orientation',
#  'https://www2.brockport.edu/admissions/orientation/first-year',
#  'https://www2.brockport.edu/admissions/orientation/first-year/orientation-leader',
#  'https://www2.brockport.edu/admissions/request',
#  'https://www2.brockport.edu/admissions/test-optional',
#  'https://www2.brockport.edu/admissions/transferring-general-education-credits',
#  'https://www2.brockport.edu/admissions/undergraduate',
#  'https://www2.brockport.edu/admissions/visit',
#  'https://www2.brockport.edu/admissions/visit-video',
#  'https://www2.brockport.edu/advancement-communications',
#  'https://www2.brockport.edu/advancement-communications/directory',
#  'https://www2.brockport.edu/advancement-communications/newsletters',
#  'https://www2.brockport.edu/go/ems',
#  'https://www2.brockport.edu/go/online',
#  'https://www2.brockport.edu/go/update-directory',
#  'https://www2.brockport.edu/graduate',
#  'https://www2.brockport.edu/graduate/about',
#  'https://www2.brockport.edu/graduate/accreditation',
#  'https://www2.brockport.edu/graduate/admissions',
#  'https://www2.brockport.edu/graduate/checklist',
#  'https://www2.brockport.edu/graduate/current-student-faq',
#  'https://www2.brockport.edu/graduate/current-students',
#  'https://www2.brockport.edu/graduate/directory',
#  'https://www2.brockport.edu/graduate/faculty-staff',
#  'https://www2.brockport.edu/graduate/financing',
#  'https://www2.brockport.edu/graduate/forms',
#  'https://www2.brockport.edu/graduate/future-students',
#  'https://www2.brockport.edu/graduate/graduate-student-guide',
#  'https://www2.brockport.edu/graduate/profiles',
#  'https://www2.brockport.edu/graduate/student-ambassadors',
#  'https://www2.brockport.edu/info/amazon',
#  'https://www2.brockport.edu/info/int-why-choose-brockport',
#  'https://www2.brockport.edu/library',
#  'https://www2.brockport.edu/library/ask',
#  'https://www2.brockport.edu/library/consultation',
#  'https://www2.brockport.edu/library/directory',
#  'https://www2.brockport.edu/library/hours',
#  'https://www2.brockport.edu/library/ill',
#  'https://www2.brockport.edu/library/lookup',
#  'https://www2.brockport.edu/life',
#  'https://www2.brockport.edu/quick-links',
#  'https://www2.brockport.edu/scholarships-aid',
#  'https://www2.brockport.edu/scholarships-aid/excelsior',
#  'https://www2.brockport.edu/scholarships-aid/financial-aid',
#  'https://www2.brockport.edu/scholarships-aid/scholarships',
#  'https://www2.brockport.edu/support/administration-finance',
#  'https://www2.brockport.edu/support/assistive-technology',
#  'https://www2.brockport.edu/support/budget',
#  'https://www2.brockport.edu/support/child-development-center',
#  'https://www2.brockport.edu/support/college-senate',
#  'https://www2.brockport.edu/support/current-students',
#  'https://www2.brockport.edu/support/emergency',
#  'https://www2.brockport.edu/support/employee-assistance-program',
#  'https://www2.brockport.edu/support/employee-success-center',
#  'https://www2.brockport.edu/support/enrollment-management',
#  'https://www2.brockport.edu/support/environmental-safety',
#  'https://www2.brockport.edu/support/facilities',
#  'https://www2.brockport.edu/support/faculty-staff',
#  'https://www2.brockport.edu/support/finance-management',
#  'https://www2.brockport.edu/support/grants',
#  'https://www2.brockport.edu/support/human-resources',
#  'https://www2.brockport.edu/support/information-security',
#  'https://www2.brockport.edu/support/institutional-assessment',
#  'https://www2.brockport.edu/support/institutional-review-board',
#  'https://www2.brockport.edu/support/issue-center',
#  'https://www2.brockport.edu/support/parents',
#  'https://www2.brockport.edu/support/parking',
#  'https://www2.brockport.edu/support/planning-budgeting',
#  'https://www2.brockport.edu/support/policies',
#  'https://www2.brockport.edu/support/procurement-payment',
#  'https://www2.brockport.edu/support/registration-records',
#  'https://www2.brockport.edu/support/research-analysis',
#  'https://www2.brockport.edu/support/student-accounts',
#  'https://www2.brockport.edu/support/student-affairs',
#  'https://www2.brockport.edu/support/student-behavioral-consultant-team',
#  'https://www2.brockport.edu/support/summer-leap',
#  'https://www2.brockport.edu/support/university-communications',
#  'https://www2.brockport.edu/support/university-events',
#  'https://www2.brockport.edu/support/university-police']

# %%
for item in list(responses_dict.values()):
    if item.status_code != 200:
        print(item.status_code)
# Out:
# 404
# 404
# 403
# 404
# 404
# 404
# 404
# 404
# 404
# 404
# 404
# 404
# 404
# 404
# 404
# 403
# 404
# 404
# 404
# 404
# 404
# 404
# 404
# 403
# 404
# 404
# 403
# 404
# 404
# 404
# 404
# 404
# 404
# 404
# 404
# 404
# 404
# 404
# 404
# 404
# 403
# 403
# 403
# 404
# 404
# 404
# 404
# 404
# 404
# 404
# 404
# 404
# 404
# 404
# 404
# 404
# 404
# 404
# 404
# 404
# 404
# 404
# 404
# 404
# 404
# 404
# 404
# 404
# 403
# 404

# %%
urls = responses_dict.keys()

## Many of the URLs have .html on he end of it. This causes some duplication where there is a url with a .html and another without.
# This step filters them out, and standardizes it. If both exist, it'll remove the .html version, if only the .html version exists, it'll strip it and add it to the list.
html_urls = set()
non_html_urls = set()

for url in urls:
    if url.endswith('.html'):
        stripped_url = url[:-5]  # strip .html
        html_urls.add(stripped_url)
    else:
        non_html_urls.add(url)

# Filter out .html URLs if non-html version exists
urls = set(non_html_urls | (html_urls - non_html_urls))

# standardize the _ and - 
urls = [url.replace('_', '-') for url in urls]



urls = set([key for key in urls for word in ['brockport.edu/live/', 'brockport.edu/life/'] if word not in key and key.count('/') < 5 and key.count('?') == 0])

for url in sorted(final):
    print(url)
# Out:
# https://www2.brockport.edu
# https://www2.brockport.edu/about
# https://www2.brockport.edu/about/accountability
# https://www2.brockport.edu/about/archives
# https://www2.brockport.edu/about/brockport-downtown
# https://www2.brockport.edu/about/college-calendar
# https://www2.brockport.edu/about/contact-us
# https://www2.brockport.edu/about/diversity
# https://www2.brockport.edu/about/economic-impact
# https://www2.brockport.edu/about/facts
# https://www2.brockport.edu/academics/public-administration
# https://www2.brockport.edu/academics/public-health
# https://www2.brockport.edu/academics/recreation-leisure
# https://www2.brockport.edu/academics/scholars-day
# https://www2.brockport.edu/academics/school-arts-sciences
# https://www2.brockport.edu/academics/school-business-management
# https://www2.brockport.edu/academics/school-education-health-human
# https://www2.brockport.edu/academics/schools-departments
# https://www2.brockport.edu/academics/social-work
# https://www2.brockport.edu/academics/sociology
# https://www2.brockport.edu/academics/special-sessions
# https://www2.brockport.edu/academics/stem
# https://www2.brockport.edu/academics/success-center
# https://www2.brockport.edu/academics/theatre-music
# https://www2.brockport.edu/academics/tutoring
# https://www2.brockport.edu/academics/ugradpgms
# https://www2.brockport.edu/academics/visual
# https://www2.brockport.edu/academics/washington
# https://www2.brockport.edu/academics/women-gender
# https://www2.brockport.edu/admissions
# https://www2.brockport.edu/admissions-aid/brockport-bound
# https://www2.brockport.edu/admissions-aid/cost
# https://www2.brockport.edu/admissions-aid/cost-previous-20-21
# https://www2.brockport.edu/admissions-aid/financial-aid
# https://www2.brockport.edu/admissions-aid/orientation
# https://www2.brockport.edu/admissions-aid/request
# https://www2.brockport.edu/admissions-aid/scholarships
# https://www2.brockport.edu/admissions-aid/visit
# https://www2.brockport.edu/admissions-aid/visit-video
# https://www2.brockport.edu/admissions/accepted
# https://www2.brockport.edu/admissions/apply
# https://www2.brockport.edu/admissions/apply-to-brockport
# https://www2.brockport.edu/admissions/brockport-bound
# https://www2.brockport.edu/admissions/contact
# https://www2.brockport.edu/admissions/cost
# https://www2.brockport.edu/admissions/cost-previous-21-22
# https://www2.brockport.edu/admissions/degree-completion
# https://www2.brockport.edu/admissions/directory
# https://www2.brockport.edu/admissions/information
# https://www2.brockport.edu/admissions/orientation
# https://www2.brockport.edu/admissions/request
# https://www2.brockport.edu/admissions/test-optional
# https://www2.brockport.edu/admissions/transfer-credit
# https://www2.brockport.edu/admissions/transferring-general-education-credits
# https://www2.brockport.edu/admissions/undergraduate
# https://www2.brockport.edu/admissions/visit
# https://www2.brockport.edu/admissions/visit-video
# https://www2.brockport.edu/advancement-communications
# https://www2.brockport.edu/advancement-communications/directory
# https://www2.brockport.edu/advancement-communications/newsletters
# https://www2.brockport.edu/coronavirus/spring-mask-update
# https://www2.brockport.edu/go/ems
# https://www2.brockport.edu/go/itservicedesk
# https://www2.brockport.edu/go/online
# https://www2.brockport.edu/go/update-directory
# https://www2.brockport.edu/graduate
# https://www2.brockport.edu/graduate/about
# https://www2.brockport.edu/graduate/accreditation
# https://www2.brockport.edu/graduate/admissions
# https://www2.brockport.edu/graduate/checklist
# https://www2.brockport.edu/graduate/current-student-faq
# https://www2.brockport.edu/graduate/current-students
# https://www2.brockport.edu/graduate/directory
# https://www2.brockport.edu/graduate/faculty-staff
# https://www2.brockport.edu/graduate/financing
# https://www2.brockport.edu/graduate/forms
# https://www2.brockport.edu/graduate/future-students
# https://www2.brockport.edu/graduate/graduate-student-guide
# https://www2.brockport.edu/graduate/profiles
# https://www2.brockport.edu/graduate/student-ambassadors
# https://www2.brockport.edu/info/amazon
# https://www2.brockport.edu/info/int-why-choose-brockport
# https://www2.brockport.edu/library
# https://www2.brockport.edu/library/ask
# https://www2.brockport.edu/library/consultation
# https://www2.brockport.edu/library/directory
# https://www2.brockport.edu/library/hours
# https://www2.brockport.edu/library/ill
# https://www2.brockport.edu/library/lookup
# https://www2.brockport.edu/life
# https://www2.brockport.edu/life/accessibility-services
# https://www2.brockport.edu/life/accomodation-resources
# https://www2.brockport.edu/life/campus-recreation
# https://www2.brockport.edu/life/community
# https://www2.brockport.edu/life/commuters
# https://www2.brockport.edu/life/counseling-center
# https://www2.brockport.edu/life/disclosures
# https://www2.brockport.edu/life/get-involved
# https://www2.brockport.edu/life/greek-life
# https://www2.brockport.edu/life/hazen-care-center
# https://www2.brockport.edu/life/health-center
# https://www2.brockport.edu/life/homecoming
# https://www2.brockport.edu/life/identity-belonging
# https://www2.brockport.edu/life/intercultural-center
# https://www2.brockport.edu/life/leadership
# https://www2.brockport.edu/life/living-learning-communities
# https://www2.brockport.edu/life/marijuana
# https://www2.brockport.edu/life/prevention-outreach
# https://www2.brockport.edu/life/residential-life
# https://www2.brockport.edu/life/safety
# https://www2.brockport.edu/life/service
# https://www2.brockport.edu/life/student-activities
# https://www2.brockport.edu/life/student-conduct
# https://www2.brockport.edu/life/student-employment
# https://www2.brockport.edu/life/union
# https://www2.brockport.edu/life/union-leadership-activities
# https://www2.brockport.edu/life/veterans
# https://www2.brockport.edu/life/welcome-week
# https://www2.brockport.edu/life/womens-center
# https://www2.brockport.edu/quick-links
# https://www2.brockport.edu/research-foundation
# https://www2.brockport.edu/research-foundation/about
# https://www2.brockport.edu/research-foundation/antisweatshop-legislation
# https://www2.brockport.edu/research-foundation/external-funding-policy
# https://www2.brockport.edu/research-foundation/external-funding-submission-process
# https://www2.brockport.edu/research-foundation/forms
# https://www2.brockport.edu/research-foundation/fringe-benefit-rates
# https://www2.brockport.edu/research-foundation/nys-mandated-time-off
# https://www2.brockport.edu/research-foundation/payroll-due-dates
# https://www2.brockport.edu/research-foundation/permits-insurance-contracts
# https://www2.brockport.edu/research-foundation/recruitment-screening-selection-procedures
# https://www2.brockport.edu/research-foundation/rental-car-faqs
# https://www2.brockport.edu/research-foundation/rental-car-policies
# https://www2.brockport.edu/research-foundation/rental-car-rates
# https://www2.brockport.edu/research-foundation/research-compliance-details
# https://www2.brockport.edu/research-foundation/responsible-conduct-of-research
# https://www2.brockport.edu/research-foundation/travel-rates-regulations
# https://www2.brockport.edu/scholarships-aid
# https://www2.brockport.edu/scholarships-aid/excelsior
# https://www2.brockport.edu/scholarships-aid/financial-aid
# https://www2.brockport.edu/scholarships-aid/scholarships
# https://www2.brockport.edu/support/administration-finance
# https://www2.brockport.edu/support/assistive-technology
# https://www2.brockport.edu/support/budget
# https://www2.brockport.edu/support/child-development-center
# https://www2.brockport.edu/support/college-senate
# https://www2.brockport.edu/support/current-students
# https://www2.brockport.edu/support/emergency
# https://www2.brockport.edu/support/employee-assistance-program
# https://www2.brockport.edu/support/employee-success-center
# https://www2.brockport.edu/support/enrollment-management
# https://www2.brockport.edu/support/environmental-safety
# https://www2.brockport.edu/support/facilities
# https://www2.brockport.edu/support/faculty-staff
# https://www2.brockport.edu/support/finance-management
# https://www2.brockport.edu/support/grants
# https://www2.brockport.edu/support/human-resources
# https://www2.brockport.edu/support/information-security
# https://www2.brockport.edu/support/institutional-assessment
# https://www2.brockport.edu/support/institutional-review-board
# https://www2.brockport.edu/support/issue-center
# https://www2.brockport.edu/support/parents
# https://www2.brockport.edu/support/parking
# https://www2.brockport.edu/support/planning-budgeting
# https://www2.brockport.edu/support/policies
# https://www2.brockport.edu/support/procurement-payment
# https://www2.brockport.edu/support/registration-records
# https://www2.brockport.edu/support/research-analysis
# https://www2.brockport.edu/support/student-accounts
# https://www2.brockport.edu/support/student-affairs
# https://www2.brockport.edu/support/student-behavioral-consultant-team
# https://www2.brockport.edu/support/summer-leap
# https://www2.brockport.edu/support/university-communications
# https://www2.brockport.edu/support/university-events
# https://www2.brockport.edu/support/university-police

# %%
len(final)
# Out:
# 249

# %%
len(final)
# Out:
# 469

# %%
len([key for key in responses_dict.keys() if word in key for word in ['admissions', 'academics']])
# Out:
# ---------------------------------------------------------------------------
# UnboundLocalError                         Traceback (most recent call last)
# Cell In[46], line 1
# ----> 1 len([key for key in responses_dict.keys() if word in key for word in ['admissions', 'academics']])
#
# Cell In[46], line 1, in <listcomp>(.0)
# ----> 1 len([key for key in responses_dict.keys() if word in key for word in ['admissions', 'academics']])
#
# UnboundLocalError: cannot access local variable 'word' where it is not associated with a value

# %%
for key in sorted(responses_dict.keys()):
    print(key)
# Out:
# https://www2.brockport.edu
# https://www2.brockport.edu/about
# https://www2.brockport.edu/about/accountability
# https://www2.brockport.edu/about/accountability/academic-assessment
# https://www2.brockport.edu/about/accountability/academic_assessment.html
# https://www2.brockport.edu/about/accountability/committees
# https://www2.brockport.edu/about/accountability/directory
# https://www2.brockport.edu/about/accountability/strategic-planning
# https://www2.brockport.edu/about/accountability/strategic_planning.html
# https://www2.brockport.edu/about/accountability/suny
# https://www2.brockport.edu/about/archives
# https://www2.brockport.edu/about/archives/about
# https://www2.brockport.edu/about/archives/college-history
# https://www2.brockport.edu/about/archives/college_history.html
# https://www2.brockport.edu/about/archives/past-presidents
# https://www2.brockport.edu/about/brockport-downtown
# https://www2.brockport.edu/about/brockport-downtown/directory
# https://www2.brockport.edu/about/brockport-downtown/event-services
# https://www2.brockport.edu/about/brockport-downtown/faculty-staff
# https://www2.brockport.edu/about/brockport-downtown/parking
# https://www2.brockport.edu/about/brockport-downtown/slideshow
# https://www2.brockport.edu/about/brockport-downtown/students
# https://www2.brockport.edu/about/brockport_downtown
# https://www2.brockport.edu/about/brockport_downtown/event_services
# https://www2.brockport.edu/about/brockport_downtown/parking
# https://www2.brockport.edu/about/brockport_downtown/slideshow.html
# https://www2.brockport.edu/about/brockport_downtown/students
# https://www2.brockport.edu/about/college_calendar
# https://www2.brockport.edu/about/contact-us
# https://www2.brockport.edu/about/contact_us
# https://www2.brockport.edu/about/diversity
# https://www2.brockport.edu/about/diversity/2022-diversity-conference
# https://www2.brockport.edu/about/diversity/about
# https://www2.brockport.edu/about/diversity/about/better-community-statement
# https://www2.brockport.edu/about/diversity/about/better_community_statement.html
# https://www2.brockport.edu/about/diversity/about/statement-definitions
# https://www2.brockport.edu/about/diversity/about/statement_definitions.html
# https://www2.brockport.edu/about/diversity/accessibility-committee
# https://www2.brockport.edu/about/diversity/all-gender-restrooms
# https://www2.brockport.edu/about/diversity/all_gender_restrooms.html
# https://www2.brockport.edu/about/diversity/ally-student
# https://www2.brockport.edu/about/diversity/bias-reporting
# https://www2.brockport.edu/about/diversity/bias-reporting-system
# https://www2.brockport.edu/about/diversity/bias-reporting/bias-reporting-dashboard
# https://www2.brockport.edu/about/diversity/bias-reporting/investigative-process
# https://www2.brockport.edu/about/diversity/briefing-sheet
# https://www2.brockport.edu/about/diversity/campus-climate-survey-results
# https://www2.brockport.edu/about/diversity/conference
# https://www2.brockport.edu/about/diversity/conference/index.html
# https://www2.brockport.edu/about/diversity/council_diversity_inclusion/index.html
# https://www2.brockport.edu/about/diversity/courses
# https://www2.brockport.edu/about/diversity/directory
# https://www2.brockport.edu/about/diversity/events
# https://www2.brockport.edu/about/diversity/events.html
# https://www2.brockport.edu/about/diversity/faculty-diversity-fellows
# https://www2.brockport.edu/about/diversity/grants-awards
# https://www2.brockport.edu/about/diversity/grants-awards/promoting-excellence-in-diversity
# https://www2.brockport.edu/about/diversity/index.html
# https://www2.brockport.edu/about/diversity/interfaith
# https://www2.brockport.edu/about/diversity/lavender-ceremony
# https://www2.brockport.edu/about/diversity/lavender_ceremony.html
# https://www2.brockport.edu/about/diversity/local-food-banks-shelters
# https://www2.brockport.edu/about/diversity/lunch-learn
# https://www2.brockport.edu/about/diversity/name-gender-identity-form
# https://www2.brockport.edu/about/diversity/restorative-champion
# https://www2.brockport.edu/about/diversity/strategic-plan
# https://www2.brockport.edu/about/diversity/strategic-plan/edi-strategic-plan-progress-2021-2022
# https://www2.brockport.edu/about/diversity/strategic_plan/edi_strategic_plan_progress_2020_2021.html
# https://www2.brockport.edu/about/diversity/strategic_plan/index.html
# https://www2.brockport.edu/about/diversity/student-advisory-board
# https://www2.brockport.edu/about/diversity/suny-edi-action-plan
# https://www2.brockport.edu/about/diversity/suny_edi_action_plan.html
# https://www2.brockport.edu/about/economic-impact
# https://www2.brockport.edu/about/facts
# https://www2.brockport.edu/about/facts/academics
# https://www2.brockport.edu/about/facts/academics.html
# https://www2.brockport.edu/about/facts/index.html
# https://www2.brockport.edu/about/location
# https://www2.brockport.edu/about/location.html
# https://www2.brockport.edu/about/lodging
# https://www2.brockport.edu/about/middlestates
# https://www2.brockport.edu/about/middlestates/2014-monitoring-report
# https://www2.brockport.edu/about/middlestates/2015-monitoring-report
# https://www2.brockport.edu/about/middlestates/2016_destination_survey_results.html
# https://www2.brockport.edu/about/middlestates/2017_destination_survey_results.html
# https://www2.brockport.edu/about/middlestates/2018_destination_survey_results.html
# https://www2.brockport.edu/about/middlestates/2019_destination_survey_results.html
# https://www2.brockport.edu/about/middlestates/about
# https://www2.brockport.edu/academics/accounting/accounting_major.html
# https://www2.brockport.edu/academics/accounting/finance_major.html
# https://www2.brockport.edu/academics/advisement
# https://www2.brockport.edu/academics/advisement/advisement
# https://www2.brockport.edu/academics/advisement/degree-audit
# https://www2.brockport.edu/academics/advisement/degree_audit
# https://www2.brockport.edu/academics/advisement/degree_audit.html
# https://www2.brockport.edu/academics/advisement/directory
# https://www2.brockport.edu/academics/advisement/faculty-staff
# https://www2.brockport.edu/academics/advisement/faculty_staff
# https://www2.brockport.edu/academics/advisement/faq
# https://www2.brockport.edu/academics/advisement/first-generation
# https://www2.brockport.edu/academics/advisement/first-year
# https://www2.brockport.edu/academics/advisement/first_generation/directory/zkennedy.html
# https://www2.brockport.edu/academics/advisement/first_generation/first_gen_day.html
# https://www2.brockport.edu/academics/advisement/first_generation/index.html
# https://www2.brockport.edu/academics/advisement/first_generation/lingo
# https://www2.brockport.edu/academics/advisement/first_generation/mentor_network
# https://www2.brockport.edu/academics/advisement/first_generation/resources
# https://www2.brockport.edu/academics/advisement/first_year.html
# https://www2.brockport.edu/academics/advisement/forms
# https://www2.brockport.edu/academics/advisement/four-year-degree-plans
# https://www2.brockport.edu/academics/advisement/gpa
# https://www2.brockport.edu/academics/advisement/gpa.html
# https://www2.brockport.edu/academics/advisement/gpa_help.html
# https://www2.brockport.edu/academics/advisement/handbook
# https://www2.brockport.edu/academics/advisement/handbook/academic-majors
# https://www2.brockport.edu/academics/advisement/handbook/academic-programs
# https://www2.brockport.edu/academics/advisement/handbook/accounting-major
# https://www2.brockport.edu/academics/advisement/handbook/advise-expectations
# https://www2.brockport.edu/academics/advisement/handbook/african-african-american-studies-major
# https://www2.brockport.edu/academics/advisement/handbook/alcohol-substance-abuse-studies-major
# https://www2.brockport.edu/academics/advisement/handbook/anthropology-major
# https://www2.brockport.edu/academics/advisement/handbook/art-bfa-major
# https://www2.brockport.edu/academics/advisement/handbook/art-major
# https://www2.brockport.edu/academics/advisement/handbook/arts-for-children-dance-major
# https://www2.brockport.edu/academics/advisement/handbook/arts-for-children-dance-studies-major
# https://www2.brockport.edu/academics/advisement/handbook/arts-for-children-interdisciplinary-major-theatre-speciality
# https://www2.brockport.edu/academics/advisement/handbook/arts-for-children-literary-major
# https://www2.brockport.edu/academics/advisement/handbook/arts-for-children-major
# https://www2.brockport.edu/academics/advisement/handbook/arts-for-children-music-major
# https://www2.brockport.edu/academics/advisement/handbook/athletic-training
# https://www2.brockport.edu/academics/advisement/handbook/biochemistry-major
# https://www2.brockport.edu/academics/advisement/handbook/biology-major
# https://www2.brockport.edu/academics/advisement/handbook/business-administration-major
# https://www2.brockport.edu/academics/advisement/handbook/chemistry-certified-major
# https://www2.brockport.edu/academics/advisement/handbook/chemistry-major
# https://www2.brockport.edu/academics/advisement/handbook/childhood-inclusive-education-bilingual-track
# https://www2.brockport.edu/academics/advisement/handbook/childhood-inclusive-education-multidisciplinary-track
# https://www2.brockport.edu/academics/advisement/handbook/communication-studies
# https://www2.brockport.edu/academics/advisement/handbook/computer-information-systems
# https://www2.brockport.edu/academics/advisement/handbook/computer-science-major
# https://www2.brockport.edu/academics/advisement/handbook/contact
# https://www2.brockport.edu/academics/advisement/handbook/contractual-liberal-arts-major
# https://www2.brockport.edu/academics/advisement/handbook/criminal-justice-major
# https://www2.brockport.edu/academics/advisement/handbook/dance-major
# https://www2.brockport.edu/academics/advisement/handbook/doctor-physical-therapy
# https://www2.brockport.edu/academics/advisement/handbook/earth-science-major
# https://www2.brockport.edu/academics/advisement/handbook/english-creative-writing-major
# https://www2.brockport.edu/academics/advisement/handbook/english-literature-major
# https://www2.brockport.edu/academics/advisement/handbook/environmental-science-major
# https://www2.brockport.edu/academics/advisement/handbook/exercise-science
# https://www2.brockport.edu/academics/advisement/handbook/finance-major
# https://www2.brockport.edu/academics/advisement/handbook/french-major
# https://www2.brockport.edu/academics/advisement/handbook/general-education
# https://www2.brockport.edu/academics/advisement/handbook/geology-major
# https://www2.brockport.edu/academics/advisement/handbook/grading-system
# https://www2.brockport.edu/academics/advisement/handbook/health-care-administration-major
# https://www2.brockport.edu/academics/advisement/handbook/health-science-major
# https://www2.brockport.edu/academics/advisement/handbook/history-major
# https://www2.brockport.edu/academics/advisement/handbook/international-business-economics-major
# https://www2.brockport.edu/academics/advisement/handbook/international-studies-major
# https://www2.brockport.edu/academics/advisement/handbook/introduction
# https://www2.brockport.edu/academics/advisement/handbook/journalism-major
# https://www2.brockport.edu/academics/advisement/handbook/kinesiology-major
# https://www2.brockport.edu/academics/advisement/handbook/liberal-studies
# https://www2.brockport.edu/academics/advisement/handbook/marketing-major
# https://www2.brockport.edu/academics/advisement/handbook/mathematics-major
# https://www2.brockport.edu/academics/advisement/handbook/medical-technology-major
# https://www2.brockport.edu/academics/advisement/handbook/meteorology-major
# https://www2.brockport.edu/academics/advisement/handbook/notes-updates
# https://www2.brockport.edu/academics/advisement/handbook/nursing-major
# https://www2.brockport.edu/academics/advisement/handbook/philosophy-major
# https://www2.brockport.edu/academics/advisement/handbook/physical-education-teaching-certification
# https://www2.brockport.edu/academics/advisement/handbook/physics-major
# https://www2.brockport.edu/academics/advisement/handbook/political-science-major
# https://www2.brockport.edu/academics/advisement/handbook/pre-health-biochemistry
# https://www2.brockport.edu/academics/advisement/handbook/pre-health-biology
# https://www2.brockport.edu/academics/advisement/handbook/pre-health-chemistry
# https://www2.brockport.edu/academics/advisement/handbook/pre-health-other
# https://www2.brockport.edu/academics/advisement/handbook/pre-law
# https://www2.brockport.edu/academics/advisement/handbook/pre_law.html
# https://www2.brockport.edu/academics/advisement/handbook/psychology-major
# https://www2.brockport.edu/academics/advisement/handbook/public-health-education-major
# https://www2.brockport.edu/academics/advisement/handbook/recreation-leisure-studies-major
# https://www2.brockport.edu/academics/advisement/handbook/social-studies-adolescence-education
# https://www2.brockport.edu/academics/advisement/handbook/social-studies-adolescence-inclusive-education
# https://www2.brockport.edu/academics/advisement/handbook/social-work-major
# https://www2.brockport.edu/academics/advisement/handbook/sociology-major
# https://www2.brockport.edu/academics/advisement/handbook/spanish-major
# https://www2.brockport.edu/academics/advisement/handbook/sport-management-major
# https://www2.brockport.edu/academics/advisement/handbook/theatre-major
# https://www2.brockport.edu/academics/advisement/handbook/water-resources-major
# https://www2.brockport.edu/academics/advisement/handbook/women-gender-studies
# https://www2.brockport.edu/academics/advisement/happi
# https://www2.brockport.edu/academics/advisement/happi.html
# https://www2.brockport.edu/academics/advisement/mission
# https://www2.brockport.edu/academics/advisement/registration
# https://www2.brockport.edu/academics/advisement/satisfactory-academic-progress-compliance
# https://www2.brockport.edu/academics/advisement/satisfactory_academic_progress_compliance.html
# https://www2.brockport.edu/academics/advisement/second-year
# https://www2.brockport.edu/academics/advisement/second-year/events
# https://www2.brockport.edu/academics/advisement/second-year/peer-mentor
# https://www2.brockport.edu/academics/advisement/second-year/resources
# https://www2.brockport.edu/academics/advisement/second-year/support
# https://www2.brockport.edu/academics/advisement/second_year
# https://www2.brockport.edu/academics/advisement/talon-academy
# https://www2.brockport.edu/academics/advisement/talon_academy.html
# https://www2.brockport.edu/academics/advisement/temporary-academic-leave
# https://www2.brockport.edu/academics/advisement/temporary_academic_leave
# https://www2.brockport.edu/academics/advisement/temporary_academic_leave.html
# https://www2.brockport.edu/academics/advisement/transfer-year
# https://www2.brockport.edu/academics/advisement/transfer-year/peer-mentor
# https://www2.brockport.edu/academics/advisement/transfer-year/taps
# https://www2.brockport.edu/academics/advisement/transfer-year/tau-sigma
# https://www2.brockport.edu/academics/advisement/transfer_year
# https://www2.brockport.edu/academics/advisement/transfer_year/peer_mentor
# https://www2.brockport.edu/academics/advisement/transfer_year/taps
# https://www2.brockport.edu/academics/advisement/transfer_year/tau_sigma
# https://www2.brockport.edu/academics/advisement/undecided
# https://www2.brockport.edu/academics/african-american
# https://www2.brockport.edu/academics/african-american/?program=major-minor
# https://www2.brockport.edu/academics/african-american/careers
# https://www2.brockport.edu/academics/african-american/directory
# https://www2.brockport.edu/academics/african-american/ghana
# https://www2.brockport.edu/academics/african-american/major-minor
# https://www2.brockport.edu/academics/african-american/major-minor/sample-four-year-degree-plan
# https://www2.brockport.edu/academics/african-american/martin-luther-king-jr
# https://www2.brockport.edu/academics/african-american/student-spotlights
# https://www2.brockport.edu/academics/african_american
# https://www2.brockport.edu/academics/aging
# https://www2.brockport.edu/academics/aging/?program=minor
# https://www2.brockport.edu/academics/aging/advanced-cert
# https://www2.brockport.edu/academics/aging/directory
# https://www2.brockport.edu/academics/american_democracy_project/constitution
# https://www2.brockport.edu/academics/anthropology
# https://www2.brockport.edu/academics/anthropology/?program=major-minor
# https://www2.brockport.edu/academics/anthropology/about
# https://www2.brockport.edu/academics/anthropology/alumni-spotlights
# https://www2.brockport.edu/academics/anthropology/anthropology-major-minor/sample-four-year-degree-plan
# https://www2.brockport.edu/academics/anthropology/career-opportunities
# https://www2.brockport.edu/academics/anthropology/directory
# https://www2.brockport.edu/academics/anthropology/ethnography
# https://www2.brockport.edu/academics/anthropology/guest-speaker
# https://www2.brockport.edu/academics/anthropology/hands-on
# https://www2.brockport.edu/academics/computing-sciences/computer-science-major-minor/career-pathways
# https://www2.brockport.edu/academics/computing-sciences/computer-science-major-minor/sample-four-year-degree-plan
# https://www2.brockport.edu/academics/computing-sciences/cybersecurity-major-minor
# https://www2.brockport.edu/academics/computing-sciences/cybersecurity-major-minor/major-curriculum-learning-outcomes
# https://www2.brockport.edu/academics/computing-sciences/cybersecurity-major-minor/minor-curriculum-learning-outcomes
# https://www2.brockport.edu/academics/computing-sciences/cybersecurity-minor
# https://www2.brockport.edu/academics/computing-sciences/directory
# https://www2.brockport.edu/academics/computing-sciences/engaged-learning
# https://www2.brockport.edu/academics/computing-sciences/enrollment-grad-data
# https://www2.brockport.edu/academics/computing-sciences/fast-facts
# https://www2.brockport.edu/academics/computing-sciences/information-systems-curriculum
# https://www2.brockport.edu/academics/computing-sciences/information-systems-major-minor
# https://www2.brockport.edu/academics/computing-sciences/mission
# https://www2.brockport.edu/academics/computing-sciences/objectives-outcomes
# https://www2.brockport.edu/academics/computing-sciences/student-alumni-spotlights
# https://www2.brockport.edu/academics/computing_sciences
# https://www2.brockport.edu/academics/computing_sciences/about/independent_study.html
# https://www2.brockport.edu/academics/computing_sciences/about/internship.html
# https://www2.brockport.edu/academics/computing_sciences/advisory.html
# https://www2.brockport.edu/academics/computing_sciences/clubs.html
# https://www2.brockport.edu/academics/computing_sciences/engaged_learning.html
# https://www2.brockport.edu/academics/computing_sciences/objectives_outcomes.html
# https://www2.brockport.edu/academics/conferences
# https://www2.brockport.edu/academics/conferences/northeastern-analysis
# https://www2.brockport.edu/academics/conferences/northeastern_analysis/accomodations.html
# ...
# https://www2.brockport.edu/support/registration-records/dates
# https://www2.brockport.edu/support/registration-records/dates/spring-deadlines
# https://www2.brockport.edu/support/registration-records/degree-works
# https://www2.brockport.edu/support/registration-records/directory
# https://www2.brockport.edu/support/registration-records/faculty-advisor
# https://www2.brockport.edu/support/registration-records/final-exam-schedule-fall
# https://www2.brockport.edu/support/registration-records/final-exam-schedule-spring
# https://www2.brockport.edu/support/registration-records/forms
# https://www2.brockport.edu/support/registration-records/graduate-transfer-credit-approval
# https://www2.brockport.edu/support/registration-records/graduation-faq
# https://www2.brockport.edu/support/registration-records/official-trans-order-info
# https://www2.brockport.edu/support/registration-records/preparing-registration
# https://www2.brockport.edu/support/registration-records/registration-faq
# https://www2.brockport.edu/support/registration-records/registration-schedule
# https://www2.brockport.edu/support/registration-records/students
# https://www2.brockport.edu/support/registration-records/verification
# https://www2.brockport.edu/support/registration_records
# https://www2.brockport.edu/support/registration_records/add_drop_faq
# https://www2.brockport.edu/support/registration_records/address_change.html
# https://www2.brockport.edu/support/registration_records/application_for_grad.html
# https://www2.brockport.edu/support/registration_records/commencement.html
# https://www2.brockport.edu/support/registration_records/course_registration
# https://www2.brockport.edu/support/registration_records/course_registration.html
# https://www2.brockport.edu/support/registration_records/credit.html
# https://www2.brockport.edu/support/registration_records/dates
# https://www2.brockport.edu/support/registration_records/dates/fall_deadlines.html
# https://www2.brockport.edu/support/registration_records/dates/index.html
# https://www2.brockport.edu/support/registration_records/degree_works.html
# https://www2.brockport.edu/support/registration_records/faculty_advisor
# https://www2.brockport.edu/support/registration_records/forms
# https://www2.brockport.edu/support/registration_records/forms.html
# https://www2.brockport.edu/support/registration_records/graduation_faq.html
# https://www2.brockport.edu/support/registration_records/index.html
# https://www2.brockport.edu/support/registration_records/official_trans_order_info.html
# https://www2.brockport.edu/support/registration_records/registration_deadline_fall_2019.html
# https://www2.brockport.edu/support/registration_records/registration_faq
# https://www2.brockport.edu/support/registration_records/registration_faq.html
# https://www2.brockport.edu/support/registration_records/registration_schedule/index.html
# https://www2.brockport.edu/support/registration_records/students
# https://www2.brockport.edu/support/registration_records/verification.html
# https://www2.brockport.edu/support/research-analysis
# https://www2.brockport.edu/support/research-analysis/data-reports
# https://www2.brockport.edu/support/research-analysis/data-reports/common-set
# https://www2.brockport.edu/support/research-analysis/directory
# https://www2.brockport.edu/support/research-analysis/qualtrics
# https://www2.brockport.edu/support/research_analysis
# https://www2.brockport.edu/support/research_analysis/data_reports/common_set.html
# https://www2.brockport.edu/support/research_analysis/data_reports/index.html
# https://www2.brockport.edu/support/research_analysis/data_reports/licensure_certification.html
# https://www2.brockport.edu/support/research_analysis/qualtrics.html
# https://www2.brockport.edu/support/research_analysis/qualtrics_terms.html
# https://www2.brockport.edu/support/student-accounts
# https://www2.brockport.edu/support/student-accounts/bill-pay-refund
# https://www2.brockport.edu/support/student-accounts/bill-pay-refund/delinquent-accts
# https://www2.brockport.edu/support/student-accounts/bill-pay-refund/e-payments
# https://www2.brockport.edu/support/student-accounts/bill-pay-refund/e-payments-auth-users
# https://www2.brockport.edu/support/student-accounts/bill-pay-refund/eBill-txt-notification
# https://www2.brockport.edu/support/student-accounts/bill-pay-refund/holds
# https://www2.brockport.edu/support/student-accounts/bill-pay-refund/processbill
# https://www2.brockport.edu/support/student-accounts/bill-pay-refund/refund-calculations
# https://www2.brockport.edu/support/student-accounts/bill-pay-refund/studentcharges
# https://www2.brockport.edu/support/student-accounts/bill-pay-refund/studentfees
# https://www2.brockport.edu/support/student-accounts/bill-pay-refund/tuition-fees-schedule
# https://www2.brockport.edu/support/student-accounts/bill-pay-refund/tuitioncost
# https://www2.brockport.edu/support/student-accounts/bill-pay-refund/tuitionwaiver
# https://www2.brockport.edu/support/student-accounts/directory
# https://www2.brockport.edu/support/student-accounts/faq-quikpay
# https://www2.brockport.edu/support/student-accounts/form-1098-t-faq
# https://www2.brockport.edu/support/student-accounts/index
# https://www2.brockport.edu/support/student-accounts/instruction
# https://www2.brockport.edu/support/student-accounts/instruction/accept-declineFA
# https://www2.brockport.edu/support/student-accounts/instruction/affirm-enrollment
# https://www2.brockport.edu/support/student-accounts/instruction/authorize-title4
# https://www2.brockport.edu/support/student-accounts/instruction/authorize-uses-QuikPAY
# https://www2.brockport.edu/support/student-accounts/instruction/enrolldirectdep
# https://www2.brockport.edu/support/student-accounts/instruction/faq
# https://www2.brockport.edu/support/student-accounts/instruction/howto-index
# https://www2.brockport.edu/support/student-accounts/instruction/instruction/viewfadisbursement
# https://www2.brockport.edu/support/student-accounts/instruction/waive-gift
# https://www2.brockport.edu/support/student-accounts/nys-tuition-status
# https://www2.brockport.edu/support/student-accounts/tax-relief-act
# https://www2.brockport.edu/support/student-accounts/tax-relief-act/reporting-fin-info
# https://www2.brockport.edu/support/student-accounts/tax-relief-act/tra-accessinginfo
# https://www2.brockport.edu/support/student-accounts/tax-relief-act/tra-additionalinfo
# https://www2.brockport.edu/support/student-accounts/tax-relief-act/tra-descriptions
# https://www2.brockport.edu/support/student-accounts/tax-relief-act/tra-qualifyingexpenses
# https://www2.brockport.edu/support/student-accounts/title4recalc
# https://www2.brockport.edu/support/student-accounts/title4recalc/authorizing-title4aid
# https://www2.brockport.edu/support/student-accounts/tuition-refund-committee
# https://www2.brockport.edu/support/student-affairs
# https://www2.brockport.edu/support/student-affairs/basic-needs
# https://www2.brockport.edu/support/student-affairs/basic-needs/clothing
# https://www2.brockport.edu/support/student-affairs/basic-needs/financial
# https://www2.brockport.edu/support/student-affairs/basic-needs/food
# https://www2.brockport.edu/support/student-affairs/basic-needs/housing
# https://www2.brockport.edu/support/student-affairs/committees
# https://www2.brockport.edu/support/student-affairs/directory
# https://www2.brockport.edu/support/student-affairs/leadership
# https://www2.brockport.edu/support/student-affairs/personal-safety-committee
# https://www2.brockport.edu/support/student-affairs/student-engagement-pillars
# https://www2.brockport.edu/support/student-affairs/units-within-the-division
# https://www2.brockport.edu/support/student-behavioral-consultant-team
# https://www2.brockport.edu/support/student-behavioral-consultant-team/about
# https://www2.brockport.edu/support/student-behavioral-consultant-team/directory
# https://www2.brockport.edu/support/student-behavioral-consultant-team/disruptive-student-guide
# https://www2.brockport.edu/support/student-behavioral-consultant-team/resources
# https://www2.brockport.edu/support/student_accounts
# https://www2.brockport.edu/support/student_accounts/bill-pay-refund/delinquent-accts.html
# https://www2.brockport.edu/support/student_accounts/bill-pay-refund/e-payments-auth_users.html
# https://www2.brockport.edu/support/student_accounts/bill-pay-refund/e-payments.html
# https://www2.brockport.edu/support/student_accounts/bill-pay-refund/eBill_txt_notification.html
# https://www2.brockport.edu/support/student_accounts/bill-pay-refund/holds.html
# https://www2.brockport.edu/support/student_accounts/bill-pay-refund/processbill.html
# https://www2.brockport.edu/support/student_accounts/bill-pay-refund/refund_calculations.html
# https://www2.brockport.edu/support/student_accounts/bill-pay-refund/studentcharges.html
# https://www2.brockport.edu/support/student_accounts/bill-pay-refund/studentfees.html
# https://www2.brockport.edu/support/student_accounts/bill-pay-refund/tuition_fees_schedule.html
# https://www2.brockport.edu/support/student_accounts/bill-pay-refund/tuitioncost.html
# https://www2.brockport.edu/support/student_accounts/bill-pay-refund/tuitionwaiver.html
# https://www2.brockport.edu/support/student_accounts/index.html
# https://www2.brockport.edu/support/student_accounts/instruction/accept-declineFA.html
# https://www2.brockport.edu/support/student_accounts/instruction/affirm-enrollment.html
# https://www2.brockport.edu/support/student_accounts/instruction/authorize-title4.html
# https://www2.brockport.edu/support/student_accounts/instruction/authorize_uses_QuikPAY.html
# https://www2.brockport.edu/support/student_accounts/instruction/enrolldirectdep.html
# https://www2.brockport.edu/support/student_accounts/instruction/waive-gift.html
# https://www2.brockport.edu/support/student_accounts/nys-finance-law/index.html
# https://www2.brockport.edu/support/student_accounts/nys-tuition-status
# https://www2.brockport.edu/support/student_accounts/nys-tuition-status/index.html
# https://www2.brockport.edu/support/student_accounts/tax-relief-act
# https://www2.brockport.edu/support/student_accounts/tax-relief-act/index.html
# https://www2.brockport.edu/support/student_accounts/tax-relief-act/reporting-fin-info.html
# https://www2.brockport.edu/support/student_accounts/tax-relief-act/tra-accessinginfo.html
# https://www2.brockport.edu/support/student_accounts/tax-relief-act/tra-additionalinfo.html
# https://www2.brockport.edu/support/student_accounts/tax-relief-act/tra-descriptions.html
# https://www2.brockport.edu/support/student_accounts/tax-relief-act/tra-qualifyingexpenses.html
# https://www2.brockport.edu/support/student_accounts/title4recalc/index.html
# https://www2.brockport.edu/support/student_behavioral_consultant_team
# https://www2.brockport.edu/support/student_behavioral_consultant_team/about.html
# https://www2.brockport.edu/support/student_behavioral_consultant_team/disruptive_student_guide.html
# https://www2.brockport.edu/support/summer-leap
# https://www2.brockport.edu/support/summer-leap/about
# https://www2.brockport.edu/support/summer-leap/arts-integration
# https://www2.brockport.edu/support/summer-leap/choice-time
# https://www2.brockport.edu/support/summer-leap/community-gatherings
# https://www2.brockport.edu/support/summer-leap/directory
# https://www2.brockport.edu/support/summer-leap/program
# https://www2.brockport.edu/support/summer-leap/summer-collaborative-2020
# https://www2.brockport.edu/support/summer-leap/summer-collaborative-2020/slideshow
# https://www2.brockport.edu/support/summer-leap/summer-learning-2022
# https://www2.brockport.edu/support/summer-leap/support
# https://www2.brockport.edu/support/summer_leap
# https://www2.brockport.edu/support/university-communications
# https://www2.brockport.edu/support/university-communications/accessibility
# https://www2.brockport.edu/support/university-communications/award
# https://www2.brockport.edu/support/university-communications/communications-strategic-plan
# https://www2.brockport.edu/support/university-communications/daily-eagle
# https://www2.brockport.edu/support/university-communications/design-marketing
# https://www2.brockport.edu/support/university-communications/design-marketing/accessibility
# https://www2.brockport.edu/support/university-communications/design-marketing/accessibility/our-process
# https://www2.brockport.edu/support/university-communications/directory
# https://www2.brockport.edu/support/university-communications/downloading-portraits
# https://www2.brockport.edu/support/university-communications/events-calendar
# https://www2.brockport.edu/support/university-communications/identity
# https://www2.brockport.edu/support/university-communications/identity/colors
# https://www2.brockport.edu/support/university-communications/identity/licensee-list
# https://www2.brockport.edu/support/university-communications/identity/logo
# https://www2.brockport.edu/support/university-communications/media
# https://www2.brockport.edu/support/university-communications/newsletters
# https://www2.brockport.edu/support/university-communications/request
# https://www2.brockport.edu/support/university-communications/social-media
# https://www2.brockport.edu/support/university-communications/student-e-newsletter
# https://www2.brockport.edu/support/university-communications/style-guide
# https://www2.brockport.edu/support/university-communications/web-team
# https://www2.brockport.edu/support/university-communications/web-team/faculty-staff-directories
# https://www2.brockport.edu/support/university-communications/web-team/request
# https://www2.brockport.edu/support/university-communications/web-team/style-guide
# https://www2.brockport.edu/support/university-communications/web-team/style-guide/graphics
# https://www2.brockport.edu/support/university-communications/web-team/style-guide/images
# https://www2.brockport.edu/support/university-communications/web-team/style-guide/links
# https://www2.brockport.edu/support/university-communications/web-team/style-guide/portraits
# https://www2.brockport.edu/support/university-communications/web-team/style-guide/templates
# https://www2.brockport.edu/support/university-communications/web-team/style-guide/type
# https://www2.brockport.edu/support/university-communications/web-team/web-accessibility
# https://www2.brockport.edu/support/university-events
# https://www2.brockport.edu/support/university-events/SERCguide
# https://www2.brockport.edu/support/university-police
# https://www2.brockport.edu/support/university-police/bluelight
# https://www2.brockport.edu/support/university-police/clery-act
# https://www2.brockport.edu/support/university-police/directory
# https://www2.brockport.edu/support/university-police/faq
# https://www2.brockport.edu/support/university-police/feedback-form
# https://www2.brockport.edu/support/university-police/mission
# https://www2.brockport.edu/support/university-police/programs
# https://www2.brockport.edu/support/university-police/rape-aggression-defense
# https://www2.brockport.edu/support/university-police/safe-exchange-zone
# https://www2.brockport.edu/support/university-police/safety-report
# https://www2.brockport.edu/support/university-police/safety-report/general-security-information
# https://www2.brockport.edu/support/university-police/safety-report/nys-penal-law-definitions
# https://www2.brockport.edu/support/university-police/safety-report/offense-definitions
# https://www2.brockport.edu/support/university-police/safety-report/policy-statements
# https://www2.brockport.edu/support/university-police/safety-report/vawa
# https://www2.brockport.edu/support/university-police/safety-tips
# https://www2.brockport.edu/support/university-police/sexual-assault
# https://www2.brockport.edu/support/university-police/student-patrol
# https://www2.brockport.edu/support/university-police/weekly-reports
# https://www2.brockport.edu/support/university_police
# https://www2.brockport.edu/support/university_police/index.html
# https://www2.brockport.edu/support/university_police/safety_report/index.html
# https://www2.brockport.edu/support/university_police/student_patrol
# https://www2.brockport.edu/support/university_police/student_patrol.html
# https://www2.brockport.edu/support/university_police/weekly_reports.html

# %%
urls = [key for key in responses_dict.keys() if '.edu/admissions/apply' in key]


## Many of the URLs have .html on he end of it. This causes some duplication where there is a url with a .html and another without.
# This step filters them out, and standardizes it. If both exist, it'll remove the .html version, if only the .html version exists, it'll strip it and add it to the list.
html_urls = set()
non_html_urls = set()

for url in urls:
    if url.endswith('.html'):
        stripped_url = url[:-5]  # strip .html
        html_urls.add(stripped_url)
    else:
        non_html_urls.add(url)

# Filter out .html URLs if non-html version exists
final_urls = list(non_html_urls | (html_urls - non_html_urls))
final_urls
# Out:
# ['https://www2.brockport.edu/admissions/apply',
#  'https://www2.brockport.edu/admissions/apply/second_degree',
#  'https://www2.brockport.edu/admissions/apply/index',
#  'https://www2.brockport.edu/admissions/apply-to-brockport',
#  'https://www2.brockport.edu/admissions/apply/special-admission-requirements',
#  'https://www2.brockport.edu/admissions/apply/dual-admission',
#  'https://www2.brockport.edu/admissions/apply/first-year',
#  'https://www2.brockport.edu/admissions/apply/non_degree',
#  'https://www2.brockport.edu/admissions/apply/readmission',
#  'https://www2.brockport.edu/admissions/apply/second-degree',
#  'https://www2.brockport.edu/admissions/apply/special-programs',
#  'https://www2.brockport.edu/admissions/apply/update',
#  'https://www2.brockport.edu/admissions/apply/dual_admission',
#  'https://www2.brockport.edu/admissions/apply/special_programs',
#  'https://www2.brockport.edu/admissions/apply/first_year',
#  'https://www2.brockport.edu/admissions/apply/special_admission_requirements',
#  'https://www2.brockport.edu/admissions/apply/status',
#  'https://www2.brockport.edu/admissions/apply/transfer',
#  'https://www2.brockport.edu/admissions/apply/faq',
#  'https://www2.brockport.edu/admissions/apply/non-degree']

# %%
# Another somewhat similar thing. I have URLs which use _ and - in the URL but point to the same webpage.
# This filters it all out.
final = list(set([url.replace('_', '-') for url in final_urls]))
final
# Out:
# ['https://www2.brockport.edu/admissions/apply',
#  'https://www2.brockport.edu/admissions/apply/readmission',
#  'https://www2.brockport.edu/admissions/apply/index',
#  'https://www2.brockport.edu/admissions/apply/second-degree',
#  'https://www2.brockport.edu/admissions/apply/faq',
#  'https://www2.brockport.edu/admissions/apply/special-programs',
#  'https://www2.brockport.edu/admissions/apply/update',
#  'https://www2.brockport.edu/admissions/apply/status',
#  'https://www2.brockport.edu/admissions/apply-to-brockport',
#  'https://www2.brockport.edu/admissions/apply/special-admission-requirements',
#  'https://www2.brockport.edu/admissions/apply/transfer',
#  'https://www2.brockport.edu/admissions/apply/dual-admission',
#  'https://www2.brockport.edu/admissions/apply/first-year',
#  'https://www2.brockport.edu/admissions/apply/non-degree']

# %%
responses_dict['https://www2.brockport.edu/go/update-directory.html']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[181], line 1
# ----> 1 responses_dict['https://www2.brockport.edu/go/update-directory.html']
#
# KeyError: 'https://www2.brockport.edu/go/update-directory.html'

# %%
import csv

# Open the CSV file in write mode
with open('urls2.csv', 'w', newline='') as file:
    writer = csv.writer(file)
    result_list = []
    # Write each URL to a new row
    for url in final:
        # Not great way, but a way to do this. I removed all the .html ones, but still need to access their contents in dictionary.
        # I'll probably change this to make it cleaner in the future.
        if url in responses_dict.keys():
            result = trafilatura.extract(responses_dict[url].text)
        else:
            result = trafilatura.extract(responses_dict[url+'.html'].text)
        
        if result not in result_list:
            result_list.append(result)
        else:
            final.remove(url)
    
    writer.writerow(['\n'])
    for url, result in zip(final, result_list):
        writer.writerow([result])

# %%
final
# Out:
# ['https://www2.brockport.edu/admissions/apply',
#  'https://www2.brockport.edu/admissions/apply/readmission',
#  'https://www2.brockport.edu/admissions/apply/second-degree',
#  'https://www2.brockport.edu/admissions/apply/faq',
#  'https://www2.brockport.edu/admissions/apply/special-programs',
#  'https://www2.brockport.edu/admissions/apply/update',
#  'https://www2.brockport.edu/admissions/apply/status',
#  'https://www2.brockport.edu/admissions/apply-to-brockport',
#  'https://www2.brockport.edu/admissions/apply/special-admission-requirements',
#  'https://www2.brockport.edu/admissions/apply/transfer',
#  'https://www2.brockport.edu/admissions/apply/dual-admission',
#  'https://www2.brockport.edu/admissions/apply/first-year',
#  'https://www2.brockport.edu/admissions/apply/non-degree']

# %%
pd.read_csv("./urls2.csv")
# Out:
#                                                    \n
# 0   SAT/ACT Test Optional\nSUNY Brockport is SAT/A...
# 1   Readmission to the University is necessary for...
# 2   I am a freshman applicant. My file is complete...
# 3   No two students are alike, and there is no one...
# 4   Students may update their admissions applicati...
# 5   If this is your first visit time logging in to...
# 6   Student Type\nFirst-time Student\nIf you are a...
# 7   A separate application or prerequisite courses...
# 8   At Brockport, you’ll find an affordable, trans...
# 9   Requirements for Dual Admission\nTo be eligibl...
# 10  Required Documents\nOnce you have started your...
# 11  Students wishing to take up to 24 credits, non...

# %%
from langchain.document_loaders.csv_loader import CSVLoader


loader = CSVLoader(file_path="./urls2.csv")
data = loader.load()

# %%
data
# Out:
# [Document(page_content=': SAT/ACT Test Optional\nSUNY Brockport is SAT/ACT test-optional. Brockport uses a holistic, full-file application review process for both admission and merit-based scholarship consideration.\nChoose Your Application\nPlease choose only ONE of the following applications to fill out. Both applications are equally accepted.\nTrack your Progress\nYou can track your application status in our online system and check for any missing documents or additional required items.\nOther Audiences\nStudents wishing to take up to 24 credits, non-degree seeking.\nStudents who have separated from the University because of an expired leave of absence, graduation, or academic dismissal.\nVisiting students are matriculated at another college but are taking classes at SUNY Brockport.\nStudents who have earned an undergraduate degree and wish to earn a second baccalaureate degree.\nStudents who have served or are serving in the US Armed Forces.\nStudents who are enrolled in a Dual Admit agreement at FLCC, GCC, MCC, or NCCC.\nInternational students should visit our Center for Global Education & Engagement website.\nSUNY Brockport does not discriminate. SUNY Brockport is an Affirmative Action/Equal Opportunity Employer. The University is committed to fostering a diverse community of outstanding faculty, staff, and students, as well as ensuring equal educational opportunity, employment, and access to services, programs, and activities, without regard to an individual’s race, color, national origin, religion, creed, age, disability, sex, gender identity, sexual orientation, familial status, pregnancy, predisposing genetic characteristics, military status, domestic violence victim status, or criminal conviction. Employees, students, applicants or other members of the University community (including but not limited to vendors, visitors, and guests) may not be subjected to harassment that is prohibited by law, or treated adversely or retaliated against based upon a protected characteristic.', metadata={'source': './urls2.csv', 'row': 0}),
#  Document(page_content=': Readmission to the University is necessary for formerly matriculated students who have separated from the University because of an expired temporary academic leave, graduation, or academic dismissal. The readmission process must be completed for you to be matriculated.\nReadmitted students are matriculated under the current catalog and are required to meet degree and program requirements in place at the time of readmission.\nSpecial Types of Readmission\nREADMISSION FOR GRADUATION PURPOSES\nStudents who wish to complete their degree requirements at another approved academic institution in order to finish their degree at SUNY Brockport must meet the following criteria:\n- Students must have a 2.0 cumulative GPA or higher at SUNY Brockport.\n- Applicants must be within 12 credits of completing their degree*.\n- Degree requirements must be completed within one year.\n- The decision to readmit must be approved by the Office of Undergraduate Admissions and the Office of Registration and Records.\n- Students in this category must not expect financial aid from SUNY Brockport.\n* Readmitted students are readmitted under the current catalog and are required\nto meet updated degree and program requirements at the time of readmission.\nREADMISSION FOR SECOND DEGREE\nPreviously enrolled undergraduate students, who wish to return to SUNY Brockport to complete a second baccalaureate degree, need to submit the Second Degree Readmission Application and provide all necessary transcripts. For more information about earning a second degree, please visit the Second Degree webpage.\nREADMISSION AFTER ACADEMIC DISMISSAL\nStudents who have been academically dismissed from the University may apply for readmission at least two academic semesters following their dismissal. Students are strongly encouraged to take at least two academically transferable courses at another college, receiving a 2.5 or better, prior to readmission.\nIn addition to the Readmission Application, applicants must submit a personal statement addressing:\n- What they have been doing since leaving the University\n- Previous academic experience while at the University\n- Factors that led to their dismissal\n- Changes made to ensure their success if offered readmission\nPlease be aware that students can only be readmitted once following an academic dismissal.\nHow to Apply\nIf you would like to be readmitted to the University, please speak with an Undergraduate Admissions advisor prior to applying.\n- When you are ready, you must submit a readmission application and the $50 application fee. You must also submit official transcripts from any colleges/universities you attended while separated from the University.\n- If more than five years have lapsed since you last attended the University, you must re-submit official transcripts from all colleges and universities you attended prior to SUNY Brockport, along with the official transcripts from colleges attended since leaving the institution.\n- A personal statement, résumé, or student biography is recommended for submission. If you were academically dismissed, you are required to write a statement (see information above).', metadata={'source': './urls2.csv', 'row': 1}),
#  Document(page_content=': I am a freshman applicant. My file is complete, but I haven’t heard yet. When can I expect to get a decision?\nAs a freshman applicant, a decision letter will be sent to you in the mail two or three weeks after a decision has been made regarding your application. Most will hear back by the end of March. Be sure to check the status of your application. We may request additional information, such as mid-year grades, before making a decision.\nMy application was complete before, and now it says incomplete. Why is that?\nWhen we review applications, we may find that we need additional information or discover that the application is not complete. Scroll to the bottom of the Application Summary page to find a list of what we need from you before we can make a decision. Please send the requested information to the Office of Undergraduate Admissions. You can find descriptions of some of our common requests here.\nI applied recently, but I can’t log on to check the status of my application.\nOnce the Application Service Center receives your application, it may take two to three weeks for it to be processed and received by the University. Therefore, your application may have not yet been received here. Please check back in a week or two. Applicants for the fall semester can access their application status beginning Sept. 1. Spring semester applicants may begin Aug. 15.\nI sent an unofficial transcript, but it says you still need my transcript to make a decision. Why is that?\nWe require all high school applicants to submit an official high school transcript and SAT/ACT scores. Transfer applicants are also required to submit official transcripts from each college attended. If admitted, you will also be required to submit official proof of high school graduation. Fax transcripts are NOT considered official.\nI applied a few weeks ago. When checking my application status, I noticed an XOF/XOD request. What does this mean, and when can I expect a decision?\nIf you have been convicted of a felony or removed from college for disciplinary reasons, additional paperwork is required in order to process your application. Extra time will be required to process that paperwork once it is received by the Undergraduate Admissions office, as other offices on campus may need to review the paperwork. Please contact our office with any questions about your particular situation.', metadata={'source': './urls2.csv', 'row': 2}),
#  Document(page_content=': No two students are alike, and there is no one way to learn. SUNY Brockport offers a number of unique and exciting programs to make your learning experience meaningful and memorable.\nHonors College\nOne of the oldest and largest among SUNY colleges, Brockport’s Honors College currently enrolls more than 300 students. As an Honors student, enjoy small classes, custom-designed coursework, and opportunities for independent, creative, and interdisciplinary study. You will work closely with distinguished professors who will be your mentors and personal advisors. Discover the highest level of your intellectual and academic ability and earn special recognition for outstanding achievement, including designation on your final college transcript.\nHonors students also receive a number of perks, which may include:\n- $6,000 Prometheus Scholarship for New York State residents or $10,000 scholarship for out-of-state students (for Fall 2022 entering first-year Honors students only; renewable up to four years)\n- Free parking pass (for eligible first-year students only; renewable up to four years)\n- Dedicated Honors College academic advisor\n- Honors House Living Learning Community\n- Honors Lounge, with free printing\n- Priority registration, housing, and early move-in date\nTo be considered for Honors, you must file a supplemental application (after you have submitted your undergraduate application to SUNY Brockport) by March 15. (The Prometheus Scholarship cannot be combined with any Extraordinary Academic Scholarships.)\nDelta College\nThe only program of its kind in the country, Delta College is a collaborative learning community for students who want to spend time on career preparation through internships and work experiences. Working with faculty mentors, enjoy a transformational learning experience that focuses on critical thinking, creative expression, experiential learning, individual reflection, independent research, and career preparation. If you are adventurous, independent, self-motivated, career-minded, and community-oriented, then Delta College may be for you.\nStudy Abroad\nOur study abroad program, one of the largest and most expansive in the United States, can take you almost anywhere in the world. With more than 100 opportunities in 31 countries on all 7 continents, our program will allow you to study at some of the most prestigious institutions worldwide, complete internships, participate in language immersion programs, and even engage in service learning.\nArmy ROTC\nBrockport’s Army Reserve Officers Training Corps (ROTC) program offers you practical training in leadership and management principles, military skills and tactics, and communication. Unlike traditional college programs, Army ROTC will give you a wide range of experiences, combining classroom instruction with hands-on training. You may pursue an officer’s commission in the US Army or enroll only in lower-division courses without incurring a military service obligation.\nNavy ROTC\nSUNY Brockport has a partnership with the University of Rochester for students interested in the United States Navy or Marine Corps. Students attend regular classes at Brockport but participate in all scheduled ROTC classes/events through the University of Rochester.\nAir Force ROTC\nSUNY Brockport has a partnership with Rochester Institute of Technology (RIT) for students interested in the United States Air Force. Attend regular classes at Brockport while participating in all scheduled ROTC classes/events through RIT.\nLeadership Development Program\nBrockport’s Leadership Development Program is designed specifically for students interested in developing their leadership skills. This comprehensive program explores leadership concepts across all academic disciplines, through a variety of curricular and cocurricular experiences and service projects.', metadata={'source': './urls2.csv', 'row': 3}),
#  Document(page_content=': Students may update their admissions application for two semesters following their original application date, provided they have either been accepted, been withdrawn, or if no decision has been made on their application.\nApplicants who have been denied admission must re-apply.\nTo update your application, please complete the form below. Once your request is received, it may take up to one week to be processed. You will be able to log onto Web Banner to verify the application update and check the status of your application.', metadata={'source': './urls2.csv', 'row': 4}),
#  Document(page_content=': If this is your first visit time logging in to the system, your PIN is your birth date (MMDDYY format). Once you log in, you will be prompted to change your PIN. Be sure to note your new PIN, as Undergraduate Admissions will not be able to tell you your new password.\nIf you did not supply your Social Security number when applying to Brockport, please contact Undergraduate Admissions to find out your Brockport Banner ID number.\nOnce logged in, your status will be indicated next to “Application Status”. If it says:\n- “Incomplete items outstanding” — Scroll to the bottom of the page to see what we need to make your application complete\n- “Complete” — We have received all necessary materials and your application is under review\n- “Decision Made” — This indicates that a decision has been made and you will receive a decision letter in the mail soon. Admissions decisions are NOT given out over the phone, in person, or via email.\nStatus Code Descriptions\nBelow are commonly used status codes that may be associated with your application. Please contact us with any questions.\nBIO — STUDENT BIOGRAPHY\nWe require a letter detailing what you have been doing academically and/or professionally since your high school graduation or last date of college attendance in order to evaluate your application. An email is sufficient. Please send it to admit@brockport.edu.\nEOG — EXPLANATION OF GRADES\nThe Admissions Committee has decided to delay making a decision on your application until we have received an explanation of your semester and/or cumulative grades below a 2.5 GPA. Please provide the Committee with a written explanation of factors that led to those grades below the minimum 2.5 GPA requirement. An email is sufficient. Please send it to admit@brockport.edu.\nEOPF — EOP DATA FORM\nPlease go to the SUNY web site to complete the EOP Financial Info form.\nHSTG — PROOF OF HIGH SCHOOL GRADUATION REQUIRED\nWe require all students to submit their final high school transcript(s) showing date of graduation.\nINVW — FURTHER ACADEMIC REVIEW\nYour application is currently being reviewed by the Admissions Committee. Once their review is complete, you will receive notification from the Office of Undergraduate Admissions via postal mail.\nIn the meantime, please contact Michael Brown, EOP Coordinator, in the Office of Undergraduate Admissions at admit@brockport.edu or (585) 395-2751 if you have any questions.\nMID — MID YEAR GRADES\nWe require your first two quarters of course work before your application will be reviewed for an admission decision. Mid-year grades are typically available from your high school counseling office late in January to mid-February. Please forward your mid-year grades to the Office of Undergraduate Admissions.\nOTH — OTHER INFORMATION\nThe Admissions Committee needs additional information as noted.\nPT2 — SUPPLEMENTAL APPLICATION\nThe Admissions Committee has decided to delay making a decision on your application until we have received the supplemental application.\nThe SUNY Supplemental application can be found here. The Common Application Supplemental form can be found here.\nRSAT — RETAKE SAT/ACT\nThe Admissions Committee suggests retaking the SAT or ACT exam. Please email the Undergraduate Admissions office if you are not planning to retake the exam(s) at admit@brockport.edu.\nTRC1 — IN-PROGRESS COURSEWORK\nThe Admissions Committee has decided to delay making a decision on your application until your in-progress grades are in. The Committee is specifically looking for continued success in your academic course work. Please be sure to send us an updated transcript when final grades are posted so your application can be reviewed at that time.\nTRC2 — IMPROVED GRADES\nThe Admissions Committee has decided to delay making a decision on your application until you have demonstrated improved academic performance. Please be sure to send us an updated transcript when final grades are posted so your appli ...
#  Document(page_content=': Student Type\nFirst-time Student\nIf you are a high school senior, homeschooled, or have never attended college, choose this option. If you have earned college credits while still in high school, we consider you a first-time student.\nGraduate Student\nFor individuals interested in study beyond the bachelor’s degree. Also combined degree programs for high parameter students seeking to complete both their bachelor’s and master’s degree within 5 years.\nTransfer Student\nIf you have attended any college after high school graduation, you should choose this option.\nInternational Student\nIf you are not a US citizen and interested in undergraduate or graduate study, you should choose this option.\nVeteran Student\nIf you have ever served or are serving in the US Armed Forces, you may be eligible for veterans or military education benefits. Students should apply as a first-time, transfer or graduate student.', metadata={'source': './urls2.csv', 'row': 6}),
#  Document(page_content=': A separate application or prerequisite courses may be required for admission to your intended major. Review our undergraduate majors and programs of study to determine if your intended major has additional requirements for admission. If your major offers a concentration, let the Office of Undergraduate Admissions know your intended concentration.\nMajors and programs with special admission requirements may change without notice. Please refer to your intended undergraduate major and program of study page for the most up-to-date information.\nChildhood and Adolescence Education Certification\nAfter acceptance to the University, students interested in our education programs (except for health science and physical education) must declare their intent to enroll in the Childhood Inclusive Generalist Program or the Adolescence Inclusive Generalist Education Program. Education is not a major at SUNY Brockport.\nChildhood and Adolescence Education Program Information\nNursing\nAll students pursuing the Bachelor of Science in Nursing (BSN) should contact the Department of Nursing prior to applying to the University. Progression into the nursing program requires a separate application to the major, as acceptance to the University does not guarantee acceptance to the nursing program. Progression into our traditional nursing program is competitive.\nThe application is open to students enrolled at Brockport (apply during your sophomore year) and transfer students.\nSocial Work\nAdmission to the Bachelor of Science in Social Work requires a separate application to the major, as acceptance to the University does not guarantee acceptance to the social work program. Admission is competitive.\nThe application is open to students enrolled at Brockport (must hold junior status) and transfer students.\nConcentrations\nSeveral majors at the University offer concentrations. We encourage you to review our undergraduate programs of study and notify the Office of Undergraduate Admissions of your intended concentration.', metadata={'source': './urls2.csv', 'row': 7}),
#  Document(page_content=': At Brockport, you’ll find an affordable, transfer-friendly education, competitive scholarships, and abundant resources along the way — all to help you complete your bachelor’s degree and reach your goals.\n*Guaranteed full junior status with an associate’s degree with a minimum of 60 and a maximum of 64 transfer credits.\nSUNY Application Common Application\nApplication Timelines\n|Semester||Deadline|\n|\n|\nFall Semester\n|\n|\nAugust 1All required documents must be received by Aug. 8\n|\n|\nSpring Semester\n|\n|\nJanuary 4\nAll required documents must be received by Jan. 10.', metadata={'source': './urls2.csv', 'row': 8}),
#  Document(page_content=': Requirements for Dual Admission\nTo be eligible to enter SUNY Brockport through dual admissions, you must meet the following criteria:\n- Be formally enrolled in a Dual Admit agreement at your current institution. (If you are unsure, please seek advisement at your local transfer center.)\n- Be attending either Finger Lakes Community College, Genesee Community College, Monroe Community College, or Niagara County Community College.\n- Have no prior degrees or college experience other than at one of the four community colleges above with which SUNY Brockport has articulation agreements.\n- Have signed the agreement with one of the above community colleges stating your intent to attend SUNY Brockport as a dual admit student upon completing your associate’s degree.\n- Achieve the minimum grade point average required to enter your intended major at SUNY Brockport.\nComplete the Intent to Enroll Form\nBy completing the form below, you have submitted your application to SUNY Brockport, and your current community college admissions office will send your official transcript to the Office of Undergraduate Admissions at Brockport. Please note:\n- Do not fill out the SUNY Application or Common Application if you are applying for dual admission.\n- It is not necessary to fill out the application until two semesters prior to attending SUNY Brockport.\nDEADLINES\nFall Enrollment: August 1\nSpring Enrollment: January 1', metadata={'source': './urls2.csv', 'row': 9}),
#  Document(page_content=': Required Documents\nOnce you have started your application in either the Common Application or the SUNY Application, you need to submit the required documents in order for your application to be processed. Work with your school counselor to ensure all appropriate materials are submitted to our office.\nAdmissions Requirements\nIn making admissions decisions, we consider a number of factors:\n- strength of your academic program\n- course grades and high school average\n- supplemental application information\n- anything additional that you supply (letters of recommendation, résumé, portfolio, etc.)\n- Standardized test scores (SAT and/or ACT) are optional to submit. Learn more\nWe understand that academic curriculums may vary from school to school.\nHOWEVER, MOST STUDENTS WHO ENTER BROCKPORT TODAY HAVE:\n- the equivalent of an Advanced Regents Diploma\n- 4 years of English\n- 3 years or more of math, sciences, and social studies\n- 3 years or more of a foreign language\n- Additional electives as appropriate\n- Some college-level course work, including Advanced Placement (AP), International Baccalaureate (IB), and college-affiliated programs such as Syracuse University Project Advance (SUPA)\nWe encourage you to work with your school counselor when preparing to apply to colleges. Brockport operates on a rolling admissions basis, which means we make decisions on applications as they become complete.\nAdditional Information\nFirst-time students who meet academic and income guidelines are eligible to apply.\nFirst-time home school students are required to submit some additional items; however, all home-school students are reviewed in the same manner as other applicants.', metadata={'source': './urls2.csv', 'row': 10}),
#  Document(page_content=': Students wishing to take up to 24 credits, non-degree seeking, without officially enrolling at SUNY Brockport may apply as a non-matriculated student.\nDeadlines\nFALL APPLICANTS: AUGUST 1\nSPRING APPLICANTS: DECEMBER 1\nApplications received after these dates will only be processed for the wait list, and admissions decisions will be made on a space-available basis.\nNon-matriculated students are eligible to register for up to six semester hours of undergraduate course work in their first semester and nine credits in any subsequent semester, provided they maintain a cumulative GPA of 2.0.\nPlease note that non-matriculated students:\n- are not eligible for financial aid;\n- receive limited academic advisement;\n- must submit all official documents (college/high school transcripts) to continue as a non-matriculated student for the following semester;\n- are subject to all changes in the course catalog if they choose to enroll at a later date;\n- are limited to a maximum of 24 credit hours as a non-matriculated student.\nNon-Matriculated Student Requirements\nTo be eligible to apply as a non-matriculated student, you must:\n- meet the same undergraduate admission requirements as freshmen or transfer students;\n- have earned a high school diploma or GED and be considered an undergraduate student (students with a bachelor’s degree should work with the Center for Graduate Studies)\n- have never been enrolled at SUNY Brockport.\nHOW TO APPLY\nComplete the Non-Matriculated Student Application and submit it along with the $25 application fee.\nNon-Matriculated Transfer Application\nNon-Matriculated High School Student Requirements\nHigh school students may enroll in one class per semester at SUNY Brockport.\nHOW TO APPLY\n- Complete a Non-Matriculated High School Student Application.\n- Submit a letter from a parent or school counselor stating that they are supportive of your interest in taking courses at the collegiate level.\n- Please bring the letter with you to the Office of Undergraduate Admissions upon applying.\nNon-Matriculated High School Student Application\nVisiting Student Requirements\nVisiting students are matriculated at another college but are taking classes at SUNY Brockport.\nHOW TO APPLY\n- Complete the Visiting Student Application.\n- You must have the application signed by your advisor (at your home institution) — indicating approval of all courses you wish to complete at SUNY Brockport and providing signed proof of your academic and disciplinary standing.\n- Submit official transcripts from each college/university from which you have received credit.\n- You must meet our current admissions standards for transfer students.\nVisiting students are responsible for tuition, fees, and charges at SUNY Brockport. Your home school must sign a consortium agreement with our Financial Aid Office for you to receive financial aid. If you are in need of financial aid, please contact the Financial Aid Office before you apply.', metadata={'source': './urls2.csv', 'row': 11})]

# %%
text_splitter = RecursiveCharacterTextSplitter(
    chunk_size=300, 
    chunk_overlap=50
)
texts = text_splitter.split_documents(data)

# %%
import re

def standardize_string(input_string):
    # Step 1: Remove '\n' characters and replace them with periods
    standardized_string = input_string.replace('\n', ' ')

    # Step 2: Standardize the number of spaces
    standardized_string = re.sub(r'\s+', ' ', standardized_string)

    # Step 3: Remove non-alphanumeric characters at the start of the string
    standardized_string = re.sub(r'^[^a-zA-Z0-9]+', '', standardized_string)

    return standardized_string.strip()

# %%
# Create new 'texts' with some additional filters
texts_cleaned = []

# Iterate over texts page_content category with this cleaning method.
for id in range(len(texts)):
    texts[id].page_content = standardize_string(texts[id].page_content)

    if len(texts[id].page_content) > 100:
        texts_cleaned.append(texts[id])

texts_cleaned
# Out:
# [Document(page_content='SAT/ACT Test Optional SUNY Brockport is SAT/ACT test-optional. Brockport uses a holistic, full-file application review process for both admission and merit-based scholarship consideration. Choose Your Application', metadata={'source': './urls2.csv', 'row': 0}),
#  Document(page_content='Choose Your Application Please choose only ONE of the following applications to fill out. Both applications are equally accepted. Track your Progress You can track your application status in our online system and check for any missing documents or additional required items. Other Audiences', metadata={'source': './urls2.csv', 'row': 0}),
#  Document(page_content='Other Audiences Students wishing to take up to 24 credits, non-degree seeking. Students who have separated from the University because of an expired leave of absence, graduation, or academic dismissal. Visiting students are matriculated at another college but are taking classes at SUNY Brockport.', metadata={'source': './urls2.csv', 'row': 0}),
#  Document(page_content='Students who have earned an undergraduate degree and wish to earn a second baccalaureate degree. Students who have served or are serving in the US Armed Forces. Students who are enrolled in a Dual Admit agreement at FLCC, GCC, MCC, or NCCC.', metadata={'source': './urls2.csv', 'row': 0}),
#  Document(page_content='SUNY Brockport does not discriminate. SUNY Brockport is an Affirmative Action/Equal Opportunity Employer. The University is committed to fostering a diverse community of outstanding faculty, staff, and students, as well as ensuring equal educational opportunity, employment, and access to services,', metadata={'source': './urls2.csv', 'row': 0}),
#  Document(page_content='opportunity, employment, and access to services, programs, and activities, without regard to an individual’s race, color, national origin, religion, creed, age, disability, sex, gender identity, sexual orientation, familial status, pregnancy, predisposing genetic characteristics, military status,', metadata={'source': './urls2.csv', 'row': 0}),
#  Document(page_content='genetic characteristics, military status, domestic violence victim status, or criminal conviction. Employees, students, applicants or other members of the University community (including but not limited to vendors, visitors, and guests) may not be subjected to harassment that is prohibited by law,', metadata={'source': './urls2.csv', 'row': 0}),
#  Document(page_content='to harassment that is prohibited by law, or treated adversely or retaliated against based upon a protected characteristic.', metadata={'source': './urls2.csv', 'row': 0}),
#  Document(page_content='Readmission to the University is necessary for formerly matriculated students who have separated from the University because of an expired temporary academic leave, graduation, or academic dismissal. The readmission process must be completed for you to be matriculated.', metadata={'source': './urls2.csv', 'row': 1}),
#  Document(page_content='Readmitted students are matriculated under the current catalog and are required to meet degree and program requirements in place at the time of readmission. Special Types of Readmission READMISSION FOR GRADUATION PURPOSES', metadata={'source': './urls2.csv', 'row': 1}),
#  Document(page_content='READMISSION FOR GRADUATION PURPOSES Students who wish to complete their degree requirements at another approved academic institution in order to finish their degree at SUNY Brockport must meet the following criteria: - Students must have a 2.0 cumulative GPA or higher at SUNY Brockport.', metadata={'source': './urls2.csv', 'row': 1}),
#  Document(page_content='Applicants must be within 12 credits of completing their degree*. - Degree requirements must be completed within one year. - The decision to readmit must be approved by the Office of Undergraduate Admissions and the Office of Registration and Records.', metadata={'source': './urls2.csv', 'row': 1}),
#  Document(page_content='Students in this category must not expect financial aid from SUNY Brockport. * Readmitted students are readmitted under the current catalog and are required to meet updated degree and program requirements at the time of readmission. READMISSION FOR SECOND DEGREE', metadata={'source': './urls2.csv', 'row': 1}),
#  Document(page_content='Previously enrolled undergraduate students, who wish to return to SUNY Brockport to complete a second baccalaureate degree, need to submit the Second Degree Readmission Application and provide all necessary transcripts. For more information about earning a second degree, please visit the Second', metadata={'source': './urls2.csv', 'row': 1}),
#  Document(page_content='Students who have been academically dismissed from the University may apply for readmission at least two academic semesters following their dismissal. Students are strongly encouraged to take at least two academically transferable courses at another college, receiving a 2.5 or better, prior to', metadata={'source': './urls2.csv', 'row': 1}),
#  Document(page_content='In addition to the Readmission Application, applicants must submit a personal statement addressing: - What they have been doing since leaving the University - Previous academic experience while at the University - Factors that led to their dismissal', metadata={'source': './urls2.csv', 'row': 1}),
#  Document(page_content='Factors that led to their dismissal - Changes made to ensure their success if offered readmission Please be aware that students can only be readmitted once following an academic dismissal. How to Apply', metadata={'source': './urls2.csv', 'row': 1}),
#  Document(page_content='How to Apply If you would like to be readmitted to the University, please speak with an Undergraduate Admissions advisor prior to applying.', metadata={'source': './urls2.csv', 'row': 1}),
#  Document(page_content='When you are ready, you must submit a readmission application and the $50 application fee. You must also submit official transcripts from any colleges/universities you attended while separated from the University.', metadata={'source': './urls2.csv', 'row': 1}),
#  Document(page_content='If more than five years have lapsed since you last attended the University, you must re-submit official transcripts from all colleges and universities you attended prior to SUNY Brockport, along with the official transcripts from colleges attended since leaving the institution.', metadata={'source': './urls2.csv', 'row': 1}),
#  Document(page_content='A personal statement, résumé, or student biography is recommended for submission. If you were academically dismissed, you are required to write a statement (see information above).', metadata={'source': './urls2.csv', 'row': 1}),
#  Document(page_content='I am a freshman applicant. My file is complete, but I haven’t heard yet. When can I expect to get a decision?', metadata={'source': './urls2.csv', 'row': 2}),
#  Document(page_content='As a freshman applicant, a decision letter will be sent to you in the mail two or three weeks after a decision has been made regarding your application. Most will hear back by the end of March. Be sure to check the status of your application. We may request additional information, such as mid-year', metadata={'source': './urls2.csv', 'row': 2}),
#  Document(page_content='When we review applications, we may find that we need additional information or discover that the application is not complete. Scroll to the bottom of the Application Summary page to find a list of what we need from you before we can make a decision. Please send the requested information to the', metadata={'source': './urls2.csv', 'row': 2}),
#  Document(page_content='Please send the requested information to the Office of Undergraduate Admissions. You can find descriptions of some of our common requests here.', metadata={'source': './urls2.csv', 'row': 2}),
#  Document(page_content='Once the Application Service Center receives your application, it may take two to three weeks for it to be processed and received by the University. Therefore, your application may have not yet been received here. Please check back in a week or two. Applicants for the fall semester can access their', metadata={'source': './urls2.csv', 'row': 2}),
#  Document(page_content='Applicants for the fall semester can access their application status beginning Sept. 1. Spring semester applicants may begin Aug. 15.', metadata={'source': './urls2.csv', 'row': 2}),
#  Document(page_content='I sent an unofficial transcript, but it says you still need my transcript to make a decision. Why is that?', metadata={'source': './urls2.csv', 'row': 2}),
#  Document(page_content='We require all high school applicants to submit an official high school transcript and SAT/ACT scores. Transfer applicants are also required to submit official transcripts from each college attended. If admitted, you will also be required to submit official proof of high school graduation. Fax', metadata={'source': './urls2.csv', 'row': 2}),
#  Document(page_content='I applied a few weeks ago. When checking my application status, I noticed an XOF/XOD request. What does this mean, and when can I expect a decision?', metadata={'source': './urls2.csv', 'row': 2}),
#  Document(page_content='If you have been convicted of a felony or removed from college for disciplinary reasons, additional paperwork is required in order to process your application. Extra time will be required to process that paperwork once it is received by the Undergraduate Admissions office, as other offices on', metadata={'source': './urls2.csv', 'row': 2}),
#  Document(page_content='Admissions office, as other offices on campus may need to review the paperwork. Please contact our office with any questions about your particular situation.', metadata={'source': './urls2.csv', 'row': 2}),
#  Document(page_content='No two students are alike, and there is no one way to learn. SUNY Brockport offers a number of unique and exciting programs to make your learning experience meaningful and memorable. Honors College', metadata={'source': './urls2.csv', 'row': 3}),
#  Document(page_content='One of the oldest and largest among SUNY colleges, Brockport’s Honors College currently enrolls more than 300 students. As an Honors student, enjoy small classes, custom-designed coursework, and opportunities for independent, creative, and interdisciplinary study. You will work closely with', metadata={'source': './urls2.csv', 'row': 3}),
#  Document(page_content='study. You will work closely with distinguished professors who will be your mentors and personal advisors. Discover the highest level of your intellectual and academic ability and earn special recognition for outstanding achievement, including designation on your final college transcript.', metadata={'source': './urls2.csv', 'row': 3}),
#  Document(page_content='Honors students also receive a number of perks, which may include: - $6,000 Prometheus Scholarship for New York State residents or $10,000 scholarship for out-of-state students (for Fall 2022 entering first-year Honors students only; renewable up to four years)', metadata={'source': './urls2.csv', 'row': 3}),
#  Document(page_content='Free parking pass (for eligible first-year students only; renewable up to four years) - Dedicated Honors College academic advisor - Honors House Living Learning Community - Honors Lounge, with free printing - Priority registration, housing, and early move-in date', metadata={'source': './urls2.csv', 'row': 3}),
#  Document(page_content='To be considered for Honors, you must file a supplemental application (after you have submitted your undergraduate application to SUNY Brockport) by March 15. (The Prometheus Scholarship cannot be combined with any Extraordinary Academic Scholarships.) Delta College', metadata={'source': './urls2.csv', 'row': 3}),
#  Document(page_content='The only program of its kind in the country, Delta College is a collaborative learning community for students who want to spend time on career preparation through internships and work experiences. Working with faculty mentors, enjoy a transformational learning experience that focuses on critical', metadata={'source': './urls2.csv', 'row': 3}),
#  Document(page_content='learning experience that focuses on critical thinking, creative expression, experiential learning, individual reflection, independent research, and career preparation. If you are adventurous, independent, self-motivated, career-minded, and community-oriented, then Delta College may be for you.', metadata={'source': './urls2.csv', 'row': 3}),
#  Document(page_content='Our study abroad program, one of the largest and most expansive in the United States, can take you almost anywhere in the world. With more than 100 opportunities in 31 countries on all 7 continents, our program will allow you to study at some of the most prestigious institutions worldwide, complete', metadata={'source': './urls2.csv', 'row': 3}),
#  Document(page_content='most prestigious institutions worldwide, complete internships, participate in language immersion programs, and even engage in service learning.', metadata={'source': './urls2.csv', 'row': 3}),
#  Document(page_content='Brockport’s Army Reserve Officers Training Corps (ROTC) program offers you practical training in leadership and management principles, military skills and tactics, and communication. Unlike traditional college programs, Army ROTC will give you a wide range of experiences, combining classroom', metadata={'source': './urls2.csv', 'row': 3}),
#  Document(page_content='a wide range of experiences, combining classroom instruction with hands-on training. You may pursue an officer’s commission in the US Army or enroll only in lower-division courses without incurring a military service obligation.', metadata={'source': './urls2.csv', 'row': 3}),
#  Document(page_content='Navy ROTC SUNY Brockport has a partnership with the University of Rochester for students interested in the United States Navy or Marine Corps. Students attend regular classes at Brockport but participate in all scheduled ROTC classes/events through the University of Rochester. Air Force ROTC', metadata={'source': './urls2.csv', 'row': 3}),
#  Document(page_content='Air Force ROTC SUNY Brockport has a partnership with Rochester Institute of Technology (RIT) for students interested in the United States Air Force. Attend regular classes at Brockport while participating in all scheduled ROTC classes/events through RIT. Leadership Development Program', metadata={'source': './urls2.csv', 'row': 3}),
#  Document(page_content='Brockport’s Leadership Development Program is designed specifically for students interested in developing their leadership skills. This comprehensive program explores leadership concepts across all academic disciplines, through a variety of curricular and cocurricular experiences and service', metadata={'source': './urls2.csv', 'row': 3}),
#  Document(page_content='Students may update their admissions application for two semesters following their original application date, provided they have either been accepted, been withdrawn, or if no decision has been made on their application. Applicants who have been denied admission must re-apply.', metadata={'source': './urls2.csv', 'row': 4}),
#  Document(page_content='To update your application, please complete the form below. Once your request is received, it may take up to one week to be processed. You will be able to log onto Web Banner to verify the application update and check the status of your application.', metadata={'source': './urls2.csv', 'row': 4}),
#  Document(page_content='If this is your first visit time logging in to the system, your PIN is your birth date (MMDDYY format). Once you log in, you will be prompted to change your PIN. Be sure to note your new PIN, as Undergraduate Admissions will not be able to tell you your new password.', metadata={'source': './urls2.csv', 'row': 5}),
#  Document(page_content='If you did not supply your Social Security number when applying to Brockport, please contact Undergraduate Admissions to find out your Brockport Banner ID number. Once logged in, your status will be indicated next to “Application Status”. If it says:', metadata={'source': './urls2.csv', 'row': 5}),
#  Document(page_content='Incomplete items outstanding” — Scroll to the bottom of the page to see what we need to make your application complete - “Complete” — We have received all necessary materials and your application is under review', metadata={'source': './urls2.csv', 'row': 5}),
#  Document(page_content='Decision Made” — This indicates that a decision has been made and you will receive a decision letter in the mail soon. Admissions decisions are NOT given out over the phone, in person, or via email. Status Code Descriptions', metadata={'source': './urls2.csv', 'row': 5}),
#  Document(page_content='Status Code Descriptions Below are commonly used status codes that may be associated with your application. Please contact us with any questions. BIO — STUDENT BIOGRAPHY', metadata={'source': './urls2.csv', 'row': 5}),
#  Document(page_content='BIO — STUDENT BIOGRAPHY We require a letter detailing what you have been doing academically and/or professionally since your high school graduation or last date of college attendance in order to evaluate your application. An email is sufficient. Please send it to admit@brockport.edu.', metadata={'source': './urls2.csv', 'row': 5}),
#  Document(page_content='The Admissions Committee has decided to delay making a decision on your application until we have received an explanation of your semester and/or cumulative grades below a 2.5 GPA. Please provide the Committee with a written explanation of factors that led to those grades below the minimum 2.5 GPA', metadata={'source': './urls2.csv', 'row': 5}),
#  Document(page_content='led to those grades below the minimum 2.5 GPA requirement. An email is sufficient. Please send it to admit@brockport.edu.', metadata={'source': './urls2.csv', 'row': 5}),
#  Document(page_content='EOPF — EOP DATA FORM Please go to the SUNY web site to complete the EOP Financial Info form. HSTG — PROOF OF HIGH SCHOOL GRADUATION REQUIRED We require all students to submit their final high school transcript(s) showing date of graduation. INVW — FURTHER ACADEMIC REVIEW', metadata={'source': './urls2.csv', 'row': 5}),
#  Document(page_content='INVW — FURTHER ACADEMIC REVIEW Your application is currently being reviewed by the Admissions Committee. Once their review is complete, you will receive notification from the Office of Undergraduate Admissions via postal mail.', metadata={'source': './urls2.csv', 'row': 5}),
#  Document(page_content='In the meantime, please contact Michael Brown, EOP Coordinator, in the Office of Undergraduate Admissions at admit@brockport.edu or (585) 395-2751 if you have any questions. MID — MID YEAR GRADES', metadata={'source': './urls2.csv', 'row': 5}),
#  Document(page_content='We require your first two quarters of course work before your application will be reviewed for an admission decision. Mid-year grades are typically available from your high school counseling office late in January to mid-February. Please forward your mid-year grades to the Office of Undergraduate', metadata={'source': './urls2.csv', 'row': 5}),
#  Document(page_content='OTH — OTHER INFORMATION The Admissions Committee needs additional information as noted. PT2 — SUPPLEMENTAL APPLICATION The Admissions Committee has decided to delay making a decision on your application until we have received the supplemental application.', metadata={'source': './urls2.csv', 'row': 5}),
#  Document(page_content='The SUNY Supplemental application can be found here. The Common Application Supplemental form can be found here. RSAT — RETAKE SAT/ACT', metadata={'source': './urls2.csv', 'row': 5}),
#  Document(page_content='RSAT — RETAKE SAT/ACT The Admissions Committee suggests retaking the SAT or ACT exam. Please email the Undergraduate Admissions office if you are not planning to retake the exam(s) at admit@brockport.edu. TRC1 — IN-PROGRESS COURSEWORK', metadata={'source': './urls2.csv', 'row': 5}),
#  Document(page_content='The Admissions Committee has decided to delay making a decision on your application until your in-progress grades are in. The Committee is specifically looking for continued success in your academic course work. Please be sure to send us an updated transcript when final grades are posted so your', metadata={'source': './urls2.csv', 'row': 5}),
#  Document(page_content='TRC2 — IMPROVED GRADES The Admissions Committee has decided to delay making a decision on your application until you have demonstrated improved academic performance. Please be sure to send us an updated transcript when final grades are posted so your application can be reviewed at that time.', metadata={'source': './urls2.csv', 'row': 5}),
#  Document(page_content='UGFV — PENDING FINANCIAL REVIEW This does not require any action on your part, as it is an internal code indicating your application is ready for financial review in the EOP process.', metadata={'source': './urls2.csv', 'row': 5}),
#  Document(page_content='Please visit the EOP site for additional information regarding documents we could possibly request from you during this process.', metadata={'source': './urls2.csv', 'row': 5}),
#  Document(page_content='Student Type First-time Student If you are a high school senior, homeschooled, or have never attended college, choose this option. If you have earned college credits while still in high school, we consider you a first-time student. Graduate Student', metadata={'source': './urls2.csv', 'row': 6}),
#  Document(page_content='Graduate Student For individuals interested in study beyond the bachelor’s degree. Also combined degree programs for high parameter students seeking to complete both their bachelor’s and master’s degree within 5 years. Transfer Student', metadata={'source': './urls2.csv', 'row': 6}),
#  Document(page_content='Transfer Student If you have attended any college after high school graduation, you should choose this option. International Student If you are not a US citizen and interested in undergraduate or graduate study, you should choose this option. Veteran Student', metadata={'source': './urls2.csv', 'row': 6}),
#  Document(page_content='Veteran Student If you have ever served or are serving in the US Armed Forces, you may be eligible for veterans or military education benefits. Students should apply as a first-time, transfer or graduate student.', metadata={'source': './urls2.csv', 'row': 6}),
#  Document(page_content='A separate application or prerequisite courses may be required for admission to your intended major. Review our undergraduate majors and programs of study to determine if your intended major has additional requirements for admission. If your major offers a concentration, let the Office of', metadata={'source': './urls2.csv', 'row': 7}),
#  Document(page_content='major offers a concentration, let the Office of Undergraduate Admissions know your intended concentration.', metadata={'source': './urls2.csv', 'row': 7}),
#  Document(page_content='Majors and programs with special admission requirements may change without notice. Please refer to your intended undergraduate major and program of study page for the most up-to-date information. Childhood and Adolescence Education Certification', metadata={'source': './urls2.csv', 'row': 7}),
#  Document(page_content='After acceptance to the University, students interested in our education programs (except for health science and physical education) must declare their intent to enroll in the Childhood Inclusive Generalist Program or the Adolescence Inclusive Generalist Education Program. Education is not a major', metadata={'source': './urls2.csv', 'row': 7}),
#  Document(page_content='All students pursuing the Bachelor of Science in Nursing (BSN) should contact the Department of Nursing prior to applying to the University. Progression into the nursing program requires a separate application to the major, as acceptance to the University does not guarantee acceptance to the', metadata={'source': './urls2.csv', 'row': 7}),
#  Document(page_content='University does not guarantee acceptance to the nursing program. Progression into our traditional nursing program is competitive.', metadata={'source': './urls2.csv', 'row': 7}),
#  Document(page_content='The application is open to students enrolled at Brockport (apply during your sophomore year) and transfer students. Social Work', metadata={'source': './urls2.csv', 'row': 7}),
#  Document(page_content='Social Work Admission to the Bachelor of Science in Social Work requires a separate application to the major, as acceptance to the University does not guarantee acceptance to the social work program. Admission is competitive.', metadata={'source': './urls2.csv', 'row': 7}),
#  Document(page_content='The application is open to students enrolled at Brockport (must hold junior status) and transfer students. Concentrations', metadata={'source': './urls2.csv', 'row': 7}),
#  Document(page_content='Concentrations Several majors at the University offer concentrations. We encourage you to review our undergraduate programs of study and notify the Office of Undergraduate Admissions of your intended concentration.', metadata={'source': './urls2.csv', 'row': 7}),
#  Document(page_content='At Brockport, you’ll find an affordable, transfer-friendly education, competitive scholarships, and abundant resources along the way — all to help you complete your bachelor’s degree and reach your goals.', metadata={'source': './urls2.csv', 'row': 8}),
#  Document(page_content='Guaranteed full junior status with an associate’s degree with a minimum of 60 and a maximum of 64 transfer credits. SUNY Application Common Application Application Timelines |Semester||Deadline| | | Fall Semester | | August 1All required documents must be received by Aug. 8 | | Spring Semester | |', metadata={'source': './urls2.csv', 'row': 8}),
#  Document(page_content='Requirements for Dual Admission To be eligible to enter SUNY Brockport through dual admissions, you must meet the following criteria: - Be formally enrolled in a Dual Admit agreement at your current institution. (If you are unsure, please seek advisement at your local transfer center.)', metadata={'source': './urls2.csv', 'row': 9}),
#  Document(page_content='Be attending either Finger Lakes Community College, Genesee Community College, Monroe Community College, or Niagara County Community College. - Have no prior degrees or college experience other than at one of the four community colleges above with which SUNY Brockport has articulation agreements.', metadata={'source': './urls2.csv', 'row': 9}),
#  Document(page_content='Have signed the agreement with one of the above community colleges stating your intent to attend SUNY Brockport as a dual admit student upon completing your associate’s degree. - Achieve the minimum grade point average required to enter your intended major at SUNY Brockport.', metadata={'source': './urls2.csv', 'row': 9}),
#  Document(page_content='Complete the Intent to Enroll Form By completing the form below, you have submitted your application to SUNY Brockport, and your current community college admissions office will send your official transcript to the Office of Undergraduate Admissions at Brockport. Please note:', metadata={'source': './urls2.csv', 'row': 9}),
#  Document(page_content='Do not fill out the SUNY Application or Common Application if you are applying for dual admission. - It is not necessary to fill out the application until two semesters prior to attending SUNY Brockport. DEADLINES Fall Enrollment: August 1 Spring Enrollment: January 1', metadata={'source': './urls2.csv', 'row': 9}),
#  Document(page_content='Once you have started your application in either the Common Application or the SUNY Application, you need to submit the required documents in order for your application to be processed. Work with your school counselor to ensure all appropriate materials are submitted to our office.', metadata={'source': './urls2.csv', 'row': 10}),
#  Document(page_content='Admissions Requirements In making admissions decisions, we consider a number of factors: - strength of your academic program - course grades and high school average - supplemental application information - anything additional that you supply (letters of recommendation, résumé, portfolio, etc.)', metadata={'source': './urls2.csv', 'row': 10}),
#  Document(page_content='Standardized test scores (SAT and/or ACT) are optional to submit. Learn more We understand that academic curriculums may vary from school to school. HOWEVER, MOST STUDENTS WHO ENTER BROCKPORT TODAY HAVE: - the equivalent of an Advanced Regents Diploma - 4 years of English', metadata={'source': './urls2.csv', 'row': 10}),
#  Document(page_content='4 years of English - 3 years or more of math, sciences, and social studies - 3 years or more of a foreign language - Additional electives as appropriate', metadata={'source': './urls2.csv', 'row': 10}),
#  Document(page_content='Additional electives as appropriate - Some college-level course work, including Advanced Placement (AP), International Baccalaureate (IB), and college-affiliated programs such as Syracuse University Project Advance (SUPA)', metadata={'source': './urls2.csv', 'row': 10}),
#  Document(page_content='We encourage you to work with your school counselor when preparing to apply to colleges. Brockport operates on a rolling admissions basis, which means we make decisions on applications as they become complete. Additional Information', metadata={'source': './urls2.csv', 'row': 10}),
#  Document(page_content='Additional Information First-time students who meet academic and income guidelines are eligible to apply. First-time home school students are required to submit some additional items; however, all home-school students are reviewed in the same manner as other applicants.', metadata={'source': './urls2.csv', 'row': 10}),
#  Document(page_content='Students wishing to take up to 24 credits, non-degree seeking, without officially enrolling at SUNY Brockport may apply as a non-matriculated student. Deadlines FALL APPLICANTS: AUGUST 1 SPRING APPLICANTS: DECEMBER 1', metadata={'source': './urls2.csv', 'row': 11}),
#  Document(page_content='SPRING APPLICANTS: DECEMBER 1 Applications received after these dates will only be processed for the wait list, and admissions decisions will be made on a space-available basis.', metadata={'source': './urls2.csv', 'row': 11}),
#  Document(page_content='Non-matriculated students are eligible to register for up to six semester hours of undergraduate course work in their first semester and nine credits in any subsequent semester, provided they maintain a cumulative GPA of 2.0. Please note that non-matriculated students:', metadata={'source': './urls2.csv', 'row': 11}),
#  Document(page_content='Please note that non-matriculated students: - are not eligible for financial aid; - receive limited academic advisement; - must submit all official documents (college/high school transcripts) to continue as a non-matriculated student for the following semester;', metadata={'source': './urls2.csv', 'row': 11}),
#  Document(page_content='are subject to all changes in the course catalog if they choose to enroll at a later date; - are limited to a maximum of 24 credit hours as a non-matriculated student. Non-Matriculated Student Requirements To be eligible to apply as a non-matriculated student, you must:', metadata={'source': './urls2.csv', 'row': 11}),
#  Document(page_content='meet the same undergraduate admission requirements as freshmen or transfer students; - have earned a high school diploma or GED and be considered an undergraduate student (students with a bachelor’s degree should work with the Center for Graduate Studies)', metadata={'source': './urls2.csv', 'row': 11}),
#  Document(page_content='have never been enrolled at SUNY Brockport. HOW TO APPLY Complete the Non-Matriculated Student Application and submit it along with the $25 application fee. Non-Matriculated Transfer Application Non-Matriculated High School Student Requirements', metadata={'source': './urls2.csv', 'row': 11}),
#  Document(page_content='Non-Matriculated High School Student Requirements High school students may enroll in one class per semester at SUNY Brockport. HOW TO APPLY - Complete a Non-Matriculated High School Student Application.', metadata={'source': './urls2.csv', 'row': 11}),
#  Document(page_content='Submit a letter from a parent or school counselor stating that they are supportive of your interest in taking courses at the collegiate level. - Please bring the letter with you to the Office of Undergraduate Admissions upon applying. Non-Matriculated High School Student Application', metadata={'source': './urls2.csv', 'row': 11}),
#  Document(page_content='Non-Matriculated High School Student Application Visiting Student Requirements Visiting students are matriculated at another college but are taking classes at SUNY Brockport. HOW TO APPLY - Complete the Visiting Student Application.', metadata={'source': './urls2.csv', 'row': 11}),
#  Document(page_content='Complete the Visiting Student Application. - You must have the application signed by your advisor (at your home institution) — indicating approval of all courses you wish to complete at SUNY Brockport and providing signed proof of your academic and disciplinary standing.', metadata={'source': './urls2.csv', 'row': 11}),
#  Document(page_content='Submit official transcripts from each college/university from which you have received credit. - You must meet our current admissions standards for transfer students.', metadata={'source': './urls2.csv', 'row': 11}),
#  Document(page_content='Visiting students are responsible for tuition, fees, and charges at SUNY Brockport. Your home school must sign a consortium agreement with our Financial Aid Office for you to receive financial aid. If you are in need of financial aid, please contact the Financial Aid Office before you apply.', metadata={'source': './urls2.csv', 'row': 11})]

# %% [markdown]
# # Now Create Embeddings
#
# Going to try openai embeddings this time around, under Morgan's suggestion that they're the best

# %%
embedding_function = OpenAIEmbeddings()

vectordb = Chroma.from_documents(
    documents = texts_cleaned,
    embedding = embedding_function
)

# %%
retreiver = vectordb.as_retriever()
docs = retreiver.get_relevant_documents("Where do I apply")

docs
# Out:
# [Document(page_content='Choose Your Application Please choose only ONE of the following applications to fill out. Both applications are equally accepted. Track your Progress You can track your application status in our online system and check for any missing documents or additional required items. Other Audiences', metadata={'source': './urls2.csv', 'row': 0}),
#  Document(page_content='How to Apply If you would like to be readmitted to the University, please speak with an Undergraduate Admissions advisor prior to applying.', metadata={'source': './urls2.csv', 'row': 1}),
#  Document(page_content='Once you have started your application in either the Common Application or the SUNY Application, you need to submit the required documents in order for your application to be processed. Work with your school counselor to ensure all appropriate materials are submitted to our office.', metadata={'source': './urls2.csv', 'row': 10}),
#  Document(page_content='Applicants for the fall semester can access their application status beginning Sept. 1. Spring semester applicants may begin Aug. 15.', metadata={'source': './urls2.csv', 'row': 2})]

# %%
qa_chain = RetrievalQA.from_chain_type(
    llm=OpenAI(),
    chain_type="stuff",
    retriever=retreiver,
    return_source_documents=True,
    verbose=True
)

# Cite sources
def process_llm_response(llm_response):
    print(llm_response['result'])
    print('\n\nSources:')
    for source in llm_response["source_documents"]:
        print(source.metadata['source'])

# %%
query = "I got accepted! Can you give me a list of what are my next steps are?"
llm_response = qa_chain(query)
process_llm_response(llm_response)
# Out:
# > Entering new RetrievalQA chain...
#
# > Finished chain.
#  Congratulations! Once you have accepted your offer of admission, your next steps will vary depending on your program. Please refer to the New Student Checklist for a comprehensive list of tasks to complete prior to enrolling in your program. You can find the New Student Checklist at [link].
#
#
# Sources:
# ./urls2.csv
# ./urls2.csv
# ./urls2.csv
# ./urls2.csv
