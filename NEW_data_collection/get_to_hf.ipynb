# %%
import pandas as pd

gpt3 = pd.read_csv('data/gpt-3.5-data-qa.csv')

# %%
gpt3
# Out:
#                                                   url  \
# 0                         https://www2.brockport.edu/
# 1                   https://www2.brockport.edu/about/
# 2          https://www2.brockport.edu/about/title-ix/
# 3               https://www2.brockport.edu/academics/
# 4      https://www2.brockport.edu/academics/calendar/
# 5   https://www2.brockport.edu/academics/career/em...
# 6   https://www2.brockport.edu/academics/eagle-suc...
# 7              https://www2.brockport.edu/admissions/
# 8   https://www2.brockport.edu/admissions/apply-to...
# 9      https://www2.brockport.edu/admissions/request/
# 10       https://www2.brockport.edu/admissions/visit/
# 11                 https://www2.brockport.edu/alumni/
# 12  https://www2.brockport.edu/alumni/be-generous/...
# 13  https://www2.brockport.edu/graduate/current-st...
# 14                https://www2.brockport.edu/library/
# 15                   https://www2.brockport.edu/life/
# ...
