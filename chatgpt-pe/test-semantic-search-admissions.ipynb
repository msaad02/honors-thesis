# %%
import pandas as pd

# %%
from InstructorEmbedding import INSTRUCTOR
model = INSTRUCTOR('hkunlp/instructor-large')
# Out:
# load INSTRUCTOR_Transformer
# max_seq_length  512

# %%
# prepare texts with instructions
text_instruction_pairs = [
    {"instruction": "Represent the Science title:", "text": "3D ActionSLAM: wearable person tracking in multi-floor environments"},
    {"instruction": "Represent the Medicine sentence for retrieving a duplicate sentence:", "text": "Recent studies have suggested that statins, an established drug group in the prevention of cardiovascular mortality, could delay or prevent breast cancer recurrence but the effect on disease-specific mortality remains unclear."}
]

# postprocess
texts_with_instructions = []
for pair in text_instruction_pairs:
    texts_with_instructions.append([pair["instruction"], pair["text"]])

# calculate embeddings
customized_embeddings = model.encode(texts_with_instructions)

# %%
import numpy as np
from sklearn.metrics.pairwise import cosine_similarity
query  = [['Represent the Wikipedia question for retrieving supporting documents: ','where is the food stored in a yam plant']]
corpus = [['Represent the Wikipedia document for retrieval: ','Capitalism has been dominant in the Western world since the end of feudalism, but most feel[who?] that the term "mixed economies" more precisely describes most contemporary economies, due to their containing both private-owned and state-owned enterprises. In capitalism, prices determine the demand-supply scale. For example, higher demand for certain goods and services lead to higher prices and lower demand for certain goods lead to lower prices.'],
          ['Represent the Wikipedia document for retrieval: ',"The disparate impact theory is especially controversial under the Fair Housing Act because the Act regulates many activities relating to housing, insurance, and mortgage loansâ€”and some scholars have argued that the theory's use under the Fair Housing Act, combined with extensions of the Community Reinvestment Act, contributed to rise of sub-prime lending and the crash of the U.S. housing market and ensuing global economic recession"],
          ['Represent the Wikipedia document for retrieval: ','Disparate impact in United States labor law refers to practices in employment, housing, and other areas that adversely affect one group of people of a protected characteristic more than another, even though rules applied by employers or landlords are formally neutral. Although the protected classes vary by statute, most federal civil rights laws protect based on race, color, religion, national origin, and sex as protected traits, and some laws include disability status and other traits as well.']]
query_embeddings = model.encode(query)
corpus_embeddings = model.encode(corpus)
similarities = cosine_similarity(query_embeddings,corpus_embeddings)
retrieved_doc_id = np.argmax(similarities)
print(retrieved_doc_id)
# Out:
# 0

# %%
similarities
# Out:
# array([[0.71853006, 0.7037146 , 0.696959  ]], dtype=float32)

# %%
data = pd.read_csv("../data-collection/data/chunks_from_html.csv", names=['source', 'data'])
display(data)
# Out:
#                                                  source  \
# 0     https://www2.brockport.edu/academics/career/al...
# 1       https://www2.brockport.edu/support/issue-center
# 2       https://www2.brockport.edu/admissions_aid/visit
# 3     https://www2.brockport.edu/support/student_acc...
# 4     https://www2.brockport.edu/academics/career/em...
# ...                                                 ...
# 3600  https://www2.brockport.edu/live/profiles/1803-...
# 3601  https://www2.brockport.edu/support/college_com...
# 3602  https://www2.brockport.edu/live/profiles/1579-...
# 3603  https://www2.brockport.edu/live/blurbs/2145-is...
# 3604     https://www2.brockport.edu/live/profiles/1295-
#
#                                                    data
# 0     Whether you are a recent graduate or a profess...
# 1     SUNY Brockport is committed to providing a saf...
# 2     Start picturing yourself here. We offer guided...
# 3     The University is no longer issuing paper stud...
# 4     Learn about ways to get involved with our camp...
# ...                                                 ...
# 3600  Recipient of Best Presenter Award, Global Mana...
# 3601  A table of contents has a different style of s...
# 3602  Joseph Long works primarily in the philosophy ...
# 3603  Larry Brien was recently featured on the Roche...
# 3604  , R.K. Stuart, A.E. Allen, E.L. Mann, Z.I. Joh...
#
# [3605 rows x 2 columns]

# %%
data[data['source'].str.contains('brockport.edu/admissions/apply')]
# Out:
#                                                  source  \
# 11    https://www2.brockport.edu/admissions/apply-to...
# 48    https://www2.brockport.edu/admissions/apply/no...
# 267         https://www2.brockport.edu/admissions/apply
# 329   https://www2.brockport.edu/admissions/apply/se...
# 371   https://www2.brockport.edu/admissions/apply/re...
# 460   https://www2.brockport.edu/admissions/apply/tr...
# 674   https://www2.brockport.edu/admissions/apply/re...
# 717     https://www2.brockport.edu/admissions/apply/faq
# 797   https://www2.brockport.edu/admissions/apply/sp...
# 881   https://www2.brockport.edu/admissions/apply/se...
# 919   https://www2.brockport.edu/admissions/apply/sp...
# 1337  https://www2.brockport.edu/admissions/apply/in...
# 1357  https://www2.brockport.edu/admissions/apply/st...
# 1620  https://www2.brockport.edu/admissions/apply/no...
# 1639  https://www2.brockport.edu/admissions/apply/du...
# 1833  https://www2.brockport.edu/admissions/apply/fi...
# 1990  https://www2.brockport.edu/admissions/apply/sp...
# 2049  https://www2.brockport.edu/admissions/apply/up...
# 2060  https://www2.brockport.edu/admissions/apply/tr...
# 2270  https://www2.brockport.edu/admissions/apply/sp...
# 2397  https://www2.brockport.edu/admissions/apply/no...
# 2562  https://www2.brockport.edu/admissions/apply/fi...
# 2873  https://www2.brockport.edu/admissions/apply/st...
# 2913  https://www2.brockport.edu/admissions/apply/du...
#
#                                                    data
# 11    If you have attended any college after high sc...
# 48    are subject to all changes in the course catal...
# 267   Please choose only ONE of the following applic...
# 329   Students who have earned an undergraduate degr...
# 371   Readmission to the University is necessary for...
# 460   . Students with more than 54 transferrable col...
# 674   Readmission to the University is necessary for...
# 717   As a freshman applicant, a decision letter wil...
# 797   The Office of Undergraduate Admissions admits ...
# 881   Students who have earned an undergraduate degr...
# 919   The Office of Undergraduate Admissions admits ...
# 1337  Please choose only ONE of the following applic...
# 1357  If this is your first visit time logging in to...
# 1620  are subject to all changes in the course catal...
# 1639  To be eligible to enter SUNY Brockport through...
# 1833  , you need to submit the required documents in...
# 1990  No two students are alike, and there is no one...
# 2049  Students may update their admissions applicati...
# 2060  . Students with more than 54 transferrable col...
# 2270  No two students are alike, and there is no one...
# 2397  are subject to all changes in the course catal...
# 2562  , you need to submit the required documents in...
# 2873  If this is your first visit time logging in to...
# 2913  To be eligible to enter SUNY Brockport through...
